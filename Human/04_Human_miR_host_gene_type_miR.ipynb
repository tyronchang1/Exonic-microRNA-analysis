# %% [markdown]
# ## Use Gene_func file to add additional columns to the dataframe
# * This new column will have a new column called gene type. Bascially this new dataframe will tell you if the host gene is classified as a protein or non-coding gene. Also, this is applied to both exonic and intronic miRNAs.

# %% [markdown]
# ### Exonic miRNAs

# %%
import pandas as pd

# %%
import import_ipynb

# %%
import os
current_dir=os.getcwd()

# %%
csv_file_path=f'{current_dir}/Human_csv_file'

# %%
from utils.Gene_func import Gene_type, Cal_mRNA_length
# Out:
# importing Jupyter notebook from /Users/tyronchang/Desktop/exonic-microrna-analysis/github3/Human/utils/Gene_func.ipynb

# %%
### This dataframe has all exonic miR and hose genes (isoforms); I haven't dropped duplicates yet.
human_exonicmiR_df=pd.read_csv(f'{csv_file_path}/human_exonic_miR_NCBI.csv')

# %%
human_exonicmiR_df
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0             chr1            175953957          175972080          175971939
# 1             chr1            175953957          175972080          175971939
# 2             chr1            175953957          175972080          175971939
# 3             chr1            175953957          175972080          175971939
# 4             chr1            175953957          175972080          175971939
# ..             ...                  ...                ...                ...
# 509          chr22             46097925           46113928           46103479
# 510          chr22             46097925           46113928           46103479
# 511          chr22             46097925           46113928           46103479
# 512          chr22             46086166           46095238           46097919
# 513          chr22             46086166           46095563           46097919
#
# ...

# %%
human_exonicmiR_df.shape
# Out:
# (514, 19)

# %%
Gene_type(human_exonicmiR_df,'hostgene_cdsStart','hostgene_cdsEnd','gene_type')

# %%
Cal_mRNA_length(human_exonicmiR_df, 'hostgene_txStarts','hostgene_txEnds','hostgene_cdsStart','hostgene_cdsEnd','gene_type','pre_mRNA_length')

# %%
human_exonicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0           chr1            175953957          175972080          175971939
# 1           chr1            175953957          175972080          175971939
# 2           chr1            175953957          175972080          175971939
# 3           chr1            175953957          175972080          175971939
# 4           chr1            175953957          175972080          175971939
#
#    hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0        176149067               -                   13          175953957
# 1        176149067               -                   13          175953957
# 2        176175951               -                   17          175953957
# 3        176175951               -                   16          175953957
# 4        176206978               -                   20          175953957
#
# ...

# %%
def move_column(df, column, new_position):
    """This function will reassign the column to a new position."""
    col = df.pop(column)
    df.insert(new_position, column, col)
    return df

# %%
move_column(human_exonicmiR_df,'pre_mRNA_length',9)
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0             chr1            175953957          175972080          175971939
# 1             chr1            175953957          175972080          175971939
# 2             chr1            175953957          175972080          175971939
# 3             chr1            175953957          175972080          175971939
# 4             chr1            175953957          175972080          175971939
# ..             ...                  ...                ...                ...
# 509          chr22             46097925           46113928           46103479
# 510          chr22             46097925           46113928           46103479
# 511          chr22             46097925           46113928           46103479
# 512          chr22             46086166           46095238           46097919
# 513          chr22             46086166           46095563           46097919
#
# ...

# %%
### save it as a csv file
human_exonicmiR_df.to_csv(f'{csv_file_path}/human_exonic_miR(gene_type)_NCBI.csv',index=False)

# %% [markdown]
# ### Intronic miRNAs

# %%
### This dataframe has all intronic miR and hose genes (isoforms); I haven't dropped any duplicates yet.
human_intronicmiR_df=pd.read_csv(f'{csv_file_path}/human_intronic_miR_NCBI.csv')

# %%
Gene_type(human_intronicmiR_df,'hostgene_cdsStart','hostgene_cdsEnd','gene_type')

# %%
human_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          243256040        243500091          243256173
# 1           chr1          243256040        243500091          243308151
# 2           chr1          243256040        243500091          243308151
# 3           chr1          243256040        243500091          243256173
# 4           chr1          243256040        243500091          243308151
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        243499785               +       SDCCAG8      NM_006642.5      chr1
# 1        243499785               +       SDCCAG8   NM_001350247.2      chr1
# 2        243499785               +       SDCCAG8   NM_001350246.2      chr1
# 3        243499785               +       SDCCAG8   NM_001350248.2      chr1
# 4        243499785               +       SDCCAG8   NM_001350251.2      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type      miR_name  \
# ...

# %%
human_intronicmiR_df.shape
# Out:
# (8191, 16)

# %%
"""Calculate the premRNA length of the host genes for each embedded intronic miRNAs"""
Cal_mRNA_length(human_intronicmiR_df,'hostgene_TxStarts','hostgene_TxEnds',
                'hostgene_cdsStart','hostgene_cdsEnd','gene_type','pre_mRNA_length' )

# %%
human_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          243256040        243500091          243256173
# 1           chr1          243256040        243500091          243308151
# 2           chr1          243256040        243500091          243308151
# 3           chr1          243256040        243500091          243256173
# 4           chr1          243256040        243500091          243308151
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        243499785               +       SDCCAG8      NM_006642.5      chr1
# 1        243499785               +       SDCCAG8   NM_001350247.2      chr1
# 2        243499785               +       SDCCAG8   NM_001350246.2      chr1
# 3        243499785               +       SDCCAG8   NM_001350248.2      chr1
# 4        243499785               +       SDCCAG8   NM_001350251.2      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type      miR_name  \
# ...

# %%
move_column(human_intronicmiR_df,'pre_mRNA_length',5)
# Out:
#      hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0              chr1          243256040        243500091          243256173
# 1              chr1          243256040        243500091          243308151
# 2              chr1          243256040        243500091          243308151
# 3              chr1          243256040        243500091          243256173
# 4              chr1          243256040        243500091          243308151
# ...             ...                ...              ...                ...
# 8186          chr22           50387645         50445090           50393749
# 8187          chr22           50387645         50445090           50393749
# 8188          chr22           50387645         50445090           50393749
# 8189          chr22           50394051         50445090           50414623
# 8190          chr22           50394065         50445090           50394134
#
# ...

# %%
human_intronicmiR_df.to_csv(f'{csv_file_path}/human_intronic_miR(gene_type)_NCBI.csv',index=False)
