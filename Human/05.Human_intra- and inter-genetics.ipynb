# %% [markdown]
# ### Human intragenetic miRNAs(intronic/exonic miRs)

# %%
#bedtools will generate the overlapped exonic miR files--->human_exonic_miR_NCBI.tsv
import pandas as pd
import matplotlib.pyplot as plt
import os
current_dir=os.getcwd()
# /Users/tyronchang/Desktop/exonic-microrna-analysis/github/Human/Human_tsv_file/human_exonic_miR_NCBI.tsv

# %%
mRNA_miR_columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
Human_exonic_miR_df=pd.read_csv(f'{current_dir}/Human_tsv_file/human_exonic_miR_NCBI.tsv', sep='\t',header=None, names=mRNA_miR_columns)

# %%
Human_exonic_miR_df
# Out:
#      hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  \
# 0              chr1            175953957          175972080
# 1              chr1            175953957          175972080
# 2              chr1            175953957          175972080
# 3              chr1            175953957          175972080
# 4              chr1            175953957          175972080
# ...             ...                  ...                ...
# 1493          chr22             46086166           46095238
# 1494          chr22             46086166           46095238
# 1495          chr22             46086166           46095563
# 1496          chr22             46086166           46095563
# 1497          chr22             46086166           46095563
#
#       hostgene_cdsStarts  hostgene_cdsEnds hostgene_strand  exon_counts  \
# 0              175971939         176149067               -           13
# 1              175971939         176149067               -           13
# 2              175971939         176149067               -           13
# 3              175971939         176149067               -           13
# 4              175971939         176175951               -           17
# ...                  ...               ...             ...          ...
# 1493            46097919          46097919               +            3
# 1494            46097919          46097919               +            3
# 1495            46097919          46097919               +            3
# 1496            46097919          46097919               +            3
# 1497            46097919          46097919               +            3
#
#       hostgene_TxStarts  hostgene_TxEnds  mature_host_mRNA_Length  \
# 0             175953957        176162971                    19460
# 1             175953957        176162971                    19460
# 2             175953957        176175979                    19427
# 3             175953957        176175979                    19427
# 4             175953957        176184692                    19706
# ...                 ...              ...                      ...
# 1493           46086166         46097919                    11634
# 1494           46086166         46097919                    11634
# 1495           46086166         46097919                    11634
# 1496           46086166         46097919                    11634
# 1497           46086166         46097919                    11634
#
#      hostgene_Name hostgene_NCBI_ID miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0             COP1   XM_047427799.1      chr1       175968370     175968479
# 1             COP1   XM_047427799.1      chr1       175968440     175968459
# 2             COP1   XM_017002080.3      chr1       175968370     175968479
# 3             COP1   XM_017002080.3      chr1       175968440     175968459
# 4             COP1   XM_017002071.2      chr1       175968370     175968479
# ...            ...              ...       ...             ...           ...
# 1493  LOC112268288   XR_002958733.2     chr22        46091059      46091080
# 1494  LOC112268288   XR_002958733.2     chr22        46091090      46091111
# 1495  LOC112268288   XR_002958732.2     chr22        46091044      46091126
# 1496  LOC112268288   XR_002958732.2     chr22        46091059      46091080
# 1497  LOC112268288   XR_002958732.2     chr22        46091090      46091111
#
#                       miR_type              miR_Name miR_strand  \
# 0     miRNA_primary_transcript     Name=hsa-mir-1843          -
# 1                        miRNA     Name=hsa-miR-1843          -
# 2     miRNA_primary_transcript     Name=hsa-mir-1843          -
# 3                        miRNA     Name=hsa-miR-1843          -
# 4     miRNA_primary_transcript     Name=hsa-mir-1843          -
# ...                        ...                   ...        ...
# 1493                     miRNA  Name=hsa-miR-3619-5p          +
# 1494                     miRNA  Name=hsa-miR-3619-3p          +
# 1495  miRNA_primary_transcript     Name=hsa-mir-3619          +
# 1496                     miRNA  Name=hsa-miR-3619-5p          +
# 1497                     miRNA  Name=hsa-miR-3619-3p          +
#
#                   miR_ID
# 0        Alias=MI0032314
# 1     Alias=MIMAT0039764
# 2        Alias=MI0032314
# 3     Alias=MIMAT0039764
# 4        Alias=MI0032314
# ...                  ...
# 1493  Alias=MIMAT0017999
# 1494  Alias=MIMAT0019219
# 1495     Alias=MI0016009
# 1496  Alias=MIMAT0017999
# 1497  Alias=MIMAT0019219
#
# [1498 rows x 19 columns]

# %%
Human_exonic_miR_df=Human_exonic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Human_exonic_miR_df=Human_exonic_miR_df.loc[Human_exonic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Human_exonic_miR_df['miRNA_group']='exonic miR'

# %%
Human_exonic_miR_df=Human_exonic_miR_df.drop_duplicates(subset=['miR_Name'])#### find the unique list

# %%
Human_exonic_miR_df.shape
# Out:
# (201, 8)

# %%
Human_exonic_miR_df.head()
# Out:
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1       175968370     175968479  miRNA_primary_transcript
# 32      chr1         9151668       9151777  miRNA_primary_transcript
# 39      chr1        98046070      98046171  miRNA_primary_transcript
# 42      chr1        98045242      98045351  miRNA_primary_transcript
# 45      chr1       109598893     109598967  miRNA_primary_transcript
#
#              miR_Name miR_strand           miR_ID miRNA_group
# 0   Name=hsa-mir-1843          -  Alias=MI0032314  exonic miR
# 32   Name=hsa-mir-34a          -  Alias=MI0000268  exonic miR
# 39   Name=hsa-mir-137          -  Alias=MI0000454  exonic miR
# 42  Name=hsa-mir-2682          -  Alias=MI0012063  exonic miR
# 45   Name=hsa-mir-197          +  Alias=MI0000239  exonic miR

# %%
excel_file_path=f'{current_dir}/Human_excel_file'
csv_file_path=f'{current_dir}/Human_csv_file'

# %%
Human_exonic_miR_df.to_excel(f'{excel_file_path}/Human_exonic_miR_df_unique.xlsx',index=False)
Human_exonic_miR_df.to_csv(f'{csv_file_path}/Human_exonic_miR_df_unique.csv',index=False)
### save it as a unique exonic miRNA excel or csv file for later use
### this step is to use for mapping intronic and intergenetic miRNAs
### These files only have unique list with hose genes information but not gene functions

# %% [markdown]
# #### Human intronic microRNA files
# (Run this after running bedtools_intronic_miRs.sh)

# %%
mRNA_miR_columns_2=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
###all intronic micrornas
Human_intronic_miR_df=pd.read_csv(f'{current_dir}/Human_tsv_file/human_intronic_miR_NCBI.tsv', sep='\t', header=None, names=mRNA_miR_columns_2)

# %%
Human_intronic_miR_df
# Out:
#       hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStarts  \
# 0               chr1          243256040        243500091           243256173
# 1               chr1          243256040        243500091           243256173
# 2               chr1          243256040        243500091           243256173
# 3               chr1          243256040        243500091           243308151
# 4               chr1          243256040        243500091           243308151
# ...              ...                ...              ...                 ...
# 21585          chr22           50387645         50445090            50393749
# 21586          chr22           50394051         50445090            50414623
# 21587          chr22           50394051         50445090            50414623
# 21588          chr22           50394065         50445090            50394134
# 21589          chr22           50394065         50445090            50394134
#
#        hostgene_cdsEnds hostgene_strand hostgene_Name hostgene_NCBI_ID  \
# 0             243499785               +       SDCCAG8      NM_006642.5
# 1             243499785               +       SDCCAG8      NM_006642.5
# 2             243499785               +       SDCCAG8      NM_006642.5
# 3             243499785               +       SDCCAG8   NM_001350247.2
# 4             243499785               +       SDCCAG8   NM_001350247.2
# ...                 ...             ...           ...              ...
# 21585          50444247               +        PPP6R2   XM_047441638.1
# 21586          50444247               +        PPP6R2   XM_017029133.2
# 21587          50444247               +        PPP6R2   XM_017029133.2
# 21588          50444247               +        PPP6R2   XM_011530740.3
# 21589          50444247               +        PPP6R2   XM_011530740.3
#
#       miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0          chr1       243346176     243346255  miRNA_primary_transcript
# 1          chr1       243346188     243346209                     miRNA
# 2          chr1       243346225     243346246                     miRNA
# 3          chr1       243346176     243346255  miRNA_primary_transcript
# 4          chr1       243346188     243346209                     miRNA
# ...         ...             ...           ...                       ...
# 21585     chr22        50407456      50407474                     miRNA
# 21586     chr22        50407442      50407524  miRNA_primary_transcript
# 21587     chr22        50407456      50407474                     miRNA
# 21588     chr22        50407442      50407524  miRNA_primary_transcript
# 21589     chr22        50407456      50407474                     miRNA
#
#                    miR_Name miR_strand              miR_ID
# 0         Name=hsa-mir-4677          +     Alias=MI0017308
# 1      Name=hsa-miR-4677-5p          +  Alias=MIMAT0019760
# 2      Name=hsa-miR-4677-3p          +  Alias=MIMAT0019761
# 3         Name=hsa-mir-4677          +     Alias=MI0017308
# 4      Name=hsa-miR-4677-5p          +  Alias=MIMAT0019760
# ...                     ...        ...                 ...
# 21585    Name=hsa-miR-12114          +  Alias=MIMAT0049008
# 21586    Name=hsa-mir-12114          +     Alias=MI0039716
# 21587    Name=hsa-miR-12114          +  Alias=MIMAT0049008
# 21588    Name=hsa-mir-12114          +     Alias=MI0039716
# 21589    Name=hsa-miR-12114          +  Alias=MIMAT0049008
#
# [21590 rows x 15 columns]

# %%
Human_intronic_miR_df=Human_intronic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Human_intronic_miR_df=Human_intronic_miR_df.loc[Human_intronic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Human_intronic_miR_df['miRNA_group']='intronic miR'

# %%
Human_intronic_miR_df.head()
# Out:
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1       243346176     243346255  miRNA_primary_transcript
# 3       chr1       243346176     243346255  miRNA_primary_transcript
# 6       chr1       243346176     243346255  miRNA_primary_transcript
# 9       chr1       243346176     243346255  miRNA_primary_transcript
# 12      chr1       243346176     243346255  miRNA_primary_transcript
#
#              miR_Name miR_strand           miR_ID   miRNA_group
# 0   Name=hsa-mir-4677          +  Alias=MI0017308  intronic miR
# 3   Name=hsa-mir-4677          +  Alias=MI0017308  intronic miR
# 6   Name=hsa-mir-4677          +  Alias=MI0017308  intronic miR
# 9   Name=hsa-mir-4677          +  Alias=MI0017308  intronic miR
# 12  Name=hsa-mir-4677          +  Alias=MI0017308  intronic miR

# %%
Human_intronic_miR_df=Human_intronic_miR_df.drop_duplicates(subset=['miR_Name'])#### find the unique lists of miRNAs
Human_intronic_miR_df.to_excel(f'{excel_file_path}/human_intronic_miR_NCBI_unique.xlsx',index= False)
Human_intronic_miR_df.to_csv(f'{csv_file_path}/human_intronic_miR_NCBI_unique.csv',index= False)

# %%
Human_intronic_miR_df.shape
# Out:
# (969, 8)

# %% [markdown]
# ### Human intergenetic microRNA files

# %%
columns_4=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']

# %%
###all NO host mRNA micrornas
Human_no_host_mRNA_miR_df=pd.read_csv(f'{current_dir}/Human_tsv_file/human_miR_no_hostmRNA_NCBI.tsv', sep='\t', header=None, names=columns_4)

# %%
Human_no_host_mRNA_miR_df=Human_no_host_mRNA_miR_df.loc[Human_no_host_mRNA_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Human_no_host_mRNA_miR_df['miRNA_group']='no host mRNA miR'

# %%
Human_no_host_mRNA_miR_df
# Out:
#     miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0        chr1          632615        632685  miRNA_primary_transcript
# 2        chr1         5862672       5862741  miRNA_primary_transcript
# 4        chr1        16858949      16859021  miRNA_primary_transcript
# 7        chr1        22266239      22266300  miRNA_primary_transcript
# 9        chr1        22633258      22633366  miRNA_primary_transcript
# ..        ...             ...           ...                       ...
# 924      chrX       147281943     147282030  miRNA_primary_transcript
# 927      chrX       150228004     150228083  miRNA_primary_transcript
# 930      chrX       151168222     151168326  miRNA_primary_transcript
# 932      chrX       154019920     154019989  miRNA_primary_transcript
# 934      chrY         4606120       4606228  miRNA_primary_transcript
#
#                 miR_Name miR_strand           miR_ID       miRNA_group
# 0     Name=hsa-mir-12136          -  Alias=MI0039740  no host mRNA miR
# 2      Name=hsa-mir-4689          -  Alias=MI0017322  no host mRNA miR
# 4      Name=hsa-mir-3675          -  Alias=MI0016076  no host mRNA miR
# 7      Name=hsa-mir-4418          +  Alias=MI0016754  no host mRNA miR
# 9      Name=hsa-mir-6127          -  Alias=MI0021271  no host mRNA miR
# ..                   ...        ...              ...               ...
# 924  Name=hsa-mir-514a-2          -  Alias=MI0003199  no host mRNA miR
# 927    Name=hsa-mir-2114          +  Alias=MI0010633  no host mRNA miR
# 930    Name=hsa-mir-4330          +  Alias=MI0015902  no host mRNA miR
# 932     Name=hsa-mir-718          -  Alias=MI0012489  no host mRNA miR
# 934    Name=hsa-mir-9985          +  Alias=MI0032313  no host mRNA miR
#
# [397 rows x 8 columns]

# %%
Human_no_host_mRNA_miR_df=Human_no_host_mRNA_miR_df.drop_duplicates(subset=['miR_Name'])#### this will generate a  unique list of miRNAs
Human_no_host_mRNA_miR_df.to_csv(f"{csv_file_path}/human_miR_no_hostmRNA_NCBI_unique.csv",index=False)
Human_no_host_mRNA_miR_df.to_excel(f"{excel_file_path}/human_miR_no_hostmRNA_NCBI_unique.xlsx",index=False)

# %%
Human_no_host_mRNA_miR_df.shape
# Out:
# (395, 8)

# %% [markdown]
# #### Now generate a dataframe to classify all different types of miRNAs (e.g. exonic/intronic/no_host_genes).

# %%
Human_miR_type_df=pd.concat([Human_exonic_miR_df, Human_intronic_miR_df, Human_no_host_mRNA_miR_df], axis=0)

# %%
Human_miR_type_df=Human_miR_type_df.drop(columns=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_ID','miR_strand'])

# %%
Human_miR_type_df.head()
# Out:
#              miR_Name miRNA_group
# 0   Name=hsa-mir-1843  exonic miR
# 32   Name=hsa-mir-34a  exonic miR
# 39   Name=hsa-mir-137  exonic miR
# 42  Name=hsa-mir-2682  exonic miR
# 45   Name=hsa-mir-197  exonic miR

# %%
Human_miR_type_df.shape
# Out:
# (1565, 2)

# %%
columns_3=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']

# %%
human_miR_miRBase_df=pd.read_csv(f'{current_dir}/Human_tsv_file/hsa_finalized.tsv', sep='\t', header=None, names=columns_3)
### this file contains all micrornas including 3p and 5p mature miRNAs from the miRbase

# %%
human_miR_miRBase_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1           17369         17436  miRNA_primary_transcript
# 1         chr1           17409         17431                     miRNA
# 2         chr1           17369         17391                     miRNA
# 3         chr1           30366         30503  miRNA_primary_transcript
# 4         chr1           30438         30458                     miRNA
# ...        ...             ...           ...                       ...
# 4796      chrY         2609229       2609252                     miRNA
# 4797      chrY         4606120       4606228  miRNA_primary_transcript
# 4798      chrY         4606140       4606158                     miRNA
# 4799      chrY        13479177      13479266  miRNA_primary_transcript
# 4800      chrY        13479189      13479214                     miRNA
#
#                   miR_Name miR_strand              miR_ID
# 0      Name=hsa-mir-6859-1          -     Alias=MI0022705
# 1     Name=hsa-miR-6859-5p          -  Alias=MIMAT0027618
# 2     Name=hsa-miR-6859-3p          -  Alias=MIMAT0027619
# 3      Name=hsa-mir-1302-2          +     Alias=MI0006363
# 4        Name=hsa-miR-1302          +  Alias=MIMAT0005890
# ...                    ...        ...                 ...
# 4796     Name=hsa-miR-6089          +  Alias=MIMAT0023714
# 4797     Name=hsa-mir-9985          +     Alias=MI0032313
# 4798     Name=hsa-miR-9985          +  Alias=MIMAT0039763
# 4799    Name=hsa-mir-12120          +     Alias=MI0039722
# 4800    Name=hsa-miR-12120          +  Alias=MIMAT0049014
#
# [4801 rows x 7 columns]

# %%
human_miR_miRBase_df=human_miR_miRBase_df.loc[human_miR_miRBase_df['miR_type']=="miRNA_primary_transcript"]

# %%
Human_miR_type_finalized_df=human_miR_miRBase_df.merge(Human_miR_type_df,on="miR_Name",how='left')
"""This will combine all the rest of miRNas that are niether intronic, exonic, nohost gene ones.
    In other words, these are partially overlappeed or antisense miRNAs.
"""
# Out:
# 'This will combine all the rest of miRNas that are niether intronic, exonic, nohost gene ones.\n    In other words, these are partially overlappeed or antisense miRNAs.\n'

# %%
Human_miR_type_finalized_df=Human_miR_type_finalized_df.loc[Human_miR_type_finalized_df['miR_type']=="miRNA_primary_transcript"]
Human_miR_type_finalized_df.head(50)
# Out:
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1           17369         17436  miRNA_primary_transcript
# 1       chr1           30366         30503  miRNA_primary_transcript
# 2       chr1          187891        187958  miRNA_primary_transcript
# 3       chr1          632615        632685  miRNA_primary_transcript
# 4       chr1         1167104       1167198  miRNA_primary_transcript
# 5       chr1         1167863       1167952  miRNA_primary_transcript
# 6       chr1         1169005       1169087  miRNA_primary_transcript
# 7       chr1         1296110       1296170  miRNA_primary_transcript
# 8       chr1         1312502       1312566  miRNA_primary_transcript
# 9       chr1         1339650       1339708  miRNA_primary_transcript
# 10      chr1         3127975       3128035  miRNA_primary_transcript
# 11      chr1         3560695       3560790  miRNA_primary_transcript
# 12      chr1         5862672       5862741  miRNA_primary_transcript
# 13      chr1         6429834       6429896  miRNA_primary_transcript
# 14      chr1         8866502       8866590  miRNA_primary_transcript
# 15      chr1         9151668       9151777  miRNA_primary_transcript
# 16      chr1         9967381       9967458  miRNA_primary_transcript
# 17      chr1        12029158      12029222  miRNA_primary_transcript
# 18      chr1        12166943      12167038  miRNA_primary_transcript
# 19      chr1        12191713      12191773  miRNA_primary_transcript
# 20      chr1        12578957      12579023  miRNA_primary_transcript
# 21      chr1        16858949      16859021  miRNA_primary_transcript
# 22      chr1        17277889      17277975  miRNA_primary_transcript
# 23      chr1        18883202      18883275  miRNA_primary_transcript
# 24      chr1        18897071      18897148  miRNA_primary_transcript
# 25      chr1        20633679      20633788  miRNA_primary_transcript
# 26      chr1        20988314      20988432  miRNA_primary_transcript
# 27      chr1        22266239      22266300  miRNA_primary_transcript
# 28      chr1        22633258      22633366  miRNA_primary_transcript
# 29      chr1        22719517      22719598  miRNA_primary_transcript
# 30      chr1        22863159      22863226  miRNA_primary_transcript
# 31      chr1        23044305      23044372  miRNA_primary_transcript
# 32      chr1        23929070      23929147  miRNA_primary_transcript
# 33      chr1        24919345      24919416  miRNA_primary_transcript
# 34      chr1        25023503      25023586  miRNA_primary_transcript
# 35      chr1        25906362      25906454  miRNA_primary_transcript
# 36      chr1        26554542      26554593  miRNA_primary_transcript
# 37      chr1        30739156      30739232  miRNA_primary_transcript
# 38      chr1        31758660      31758735  miRNA_primary_transcript
# 39      chr1        32086949      32087007  miRNA_primary_transcript
# 40      chr1        33332393      33332492  miRNA_primary_transcript
# 41      chr1        34669599      34669694  miRNA_primary_transcript
# 42      chr1        37161563      37161634  miRNA_primary_transcript
# 43      chr1        37480230      37480289  miRNA_primary_transcript
# 44      chr1        37500935      37500994  miRNA_primary_transcript
# 45      chr1        38089231      38089329  miRNA_primary_transcript
# 46      chr1        40754355      40754446  miRNA_primary_transcript
# 47      chr1        40757284      40757372  miRNA_primary_transcript
# 48      chr1        43171652      43171712  miRNA_primary_transcript
# 49      chr1        43364648      43364715  miRNA_primary_transcript
#
#                miR_Name miR_strand           miR_ID       miRNA_group
# 0   Name=hsa-mir-6859-1          -  Alias=MI0022705      intronic miR
# 1   Name=hsa-mir-1302-2          +  Alias=MI0006363        exonic miR
# 2   Name=hsa-mir-6859-2          -  Alias=MI0026420      intronic miR
# 3    Name=hsa-mir-12136          -  Alias=MI0039740  no host mRNA miR
# 4     Name=hsa-mir-200b          +  Alias=MI0000342        exonic miR
# 5     Name=hsa-mir-200a          +  Alias=MI0000737        exonic miR
# 6      Name=hsa-mir-429          +  Alias=MI0001641        exonic miR
# 7     Name=hsa-mir-6726          -  Alias=MI0022571      intronic miR
# 8     Name=hsa-mir-6727          -  Alias=MI0022572      intronic miR
# 9     Name=hsa-mir-6808          -  Alias=MI0022653      intronic miR
# 10    Name=hsa-mir-4251          +  Alias=MI0015861      intronic miR
# 11    Name=hsa-mir-551a          -  Alias=MI0003556      intronic miR
# 12    Name=hsa-mir-4689          -  Alias=MI0017322  no host mRNA miR
# 13    Name=hsa-mir-4252          -  Alias=MI0015864               NaN
# 14    Name=hsa-mir-6728          -  Alias=MI0022573      intronic miR
# 15     Name=hsa-mir-34a          -  Alias=MI0000268        exonic miR
# 16    Name=hsa-mir-5697          +  Alias=MI0019304      intronic miR
# 17    Name=hsa-mir-6729          +  Alias=MI0022574      intronic miR
# 18    Name=hsa-mir-7846          +  Alias=MI0025516               NaN
# 19    Name=hsa-mir-4632          +  Alias=MI0017259      intronic miR
# 20    Name=hsa-mir-6730          -  Alias=MI0022575      intronic miR
# 21    Name=hsa-mir-3675          -  Alias=MI0016076  no host mRNA miR
# 22    Name=hsa-mir-3972          +  Alias=MI0016990      intronic miR
# 23    Name=hsa-mir-4695          -  Alias=MI0017328      intronic miR
# 24    Name=hsa-mir-1290          -  Alias=MI0006352      intronic miR
# 25    Name=hsa-mir-6084          +  Alias=MI0020361        exonic miR
# 26    Name=hsa-mir-1256          -  Alias=MI0006390      intronic miR
# 27    Name=hsa-mir-4418          +  Alias=MI0016754  no host mRNA miR
# 28    Name=hsa-mir-6127          -  Alias=MI0021271  no host mRNA miR
# 29    Name=hsa-mir-4684          +  Alias=MI0017316      intronic miR
# 30    Name=hsa-mir-4253          -  Alias=MI0015860               NaN
# 31    Name=hsa-mir-3115          +  Alias=MI0014127      intronic miR
# 32    Name=hsa-mir-378f          +  Alias=MI0016756  no host mRNA miR
# 33    Name=hsa-mir-6731          -  Alias=MI0022576      intronic miR
# 34    Name=hsa-mir-4425          +  Alias=MI0016764  no host mRNA miR
# 35    Name=hsa-mir-3917          -  Alias=MI0016423               NaN
# 36    Name=hsa-mir-1976          +  Alias=MI0009986      intronic miR
# 37    Name=hsa-mir-4420          -  Alias=MI0016757      intronic miR
# 38    Name=hsa-mir-4254          -  Alias=MI0015862        exonic miR
# 39    Name=hsa-mir-5585          +  Alias=MI0019142      intronic miR
# 40    Name=hsa-mir-3605          -  Alias=MI0015995               NaN
# 41     Name=hsa-mir-552          -  Alias=MI0003557      intronic miR
# 42    Name=hsa-mir-4255          +  Alias=MI0015863  no host mRNA miR
# 43    Name=hsa-mir-6732          +  Alias=MI0022577      intronic miR
# 44    Name=hsa-mir-5581          -  Alias=MI0019136      intronic miR
# 45    Name=hsa-mir-3659          +  Alias=MI0016060      intronic miR
# 46     Name=hsa-mir-30e          +  Alias=MI0000749      intronic miR
# 47   Name=hsa-mir-30c-1          +  Alias=MI0000736      intronic miR
# 48    Name=hsa-mir-6733          -  Alias=MI0022578      intronic miR
# 49    Name=hsa-mir-6734          -  Alias=MI0022579      intronic miR

# %%
Human_miR_type_finalized_df.shape
# Out:
# (1922, 8)

# %% [markdown]
# ## Last step, here you will:
# ### 1) fill in the other empty cells with partially overlapped with exons
# ### 2) finalize the dataframe.

# %% [markdown]
# ### Human

# %%
Human_miR_type_finalized_df['miRNA_group']=Human_miR_type_finalized_df['miRNA_group'].fillna("partially overlapped with exons or opposite transcriptional units")

# %%
Human_miR_type_finalized_df['miR_Name']=Human_miR_type_finalized_df['miR_Name'].str.replace("Name=","")

# %%
Human_miR_type_finalized_df.drop_duplicates(subset=['miR_ID'],inplace=True)####drop any duplicates to remove isoforms

# %%
Human_miR_type_finalized_df.shape
# Out:
# (1913, 8)

# %%
Human_miR_type_finalized_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1           17369         17436  miRNA_primary_transcript
# 1         chr1           30366         30503  miRNA_primary_transcript
# 2         chr1          187891        187958  miRNA_primary_transcript
# 3         chr1          632615        632685  miRNA_primary_transcript
# 4         chr1         1167104       1167198  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 1917      chrX       155457517     155457615  miRNA_primary_transcript
# 1918      chrY         1293918       1293992  miRNA_primary_transcript
# 1919      chrY         2609191       2609254  miRNA_primary_transcript
# 1920      chrY         4606120       4606228  miRNA_primary_transcript
# 1921      chrY        13479177      13479266  miRNA_primary_transcript
#
#             miR_Name miR_strand           miR_ID  \
# 0     hsa-mir-6859-1          -  Alias=MI0022705
# 1     hsa-mir-1302-2          +  Alias=MI0006363
# 2     hsa-mir-6859-2          -  Alias=MI0026420
# 3      hsa-mir-12136          -  Alias=MI0039740
# 4       hsa-mir-200b          +  Alias=MI0000342
# ...              ...        ...              ...
# 1917  hsa-mir-1184-3          +  Alias=MI0015972
# 1918  hsa-mir-3690-2          +  Alias=MI0023561
# 1919  hsa-mir-6089-2          +  Alias=MI0023563
# 1920    hsa-mir-9985          +  Alias=MI0032313
# 1921   hsa-mir-12120          +  Alias=MI0039722
#
#                                             miRNA_group
# 0                                          intronic miR
# 1                                            exonic miR
# 2                                          intronic miR
# 3                                      no host mRNA miR
# 4                                            exonic miR
# ...                                                 ...
# 1917  partially overlapped with exons or opposite tr...
# 1918  partially overlapped with exons or opposite tr...
# 1919  partially overlapped with exons or opposite tr...
# 1920                                   no host mRNA miR
# 1921  partially overlapped with exons or opposite tr...
#
# [1913 rows x 8 columns]

# %% [markdown]
# ## Plotting percentages of intergenetic and intragenetic miRNAs

# %%
Human_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_group'],
#       dtype='object')

# %%
def Hostgene_type(df, miRNAgroup,hostgenetype):
    """This function will assign miRNA to certain locations -intrageneic or intergenic"""
    df[hostgenetype]=df[miRNAgroup].apply(lambda x:"intergenic" if x=="no host mRNA miR" else "intragenic")
    return df

# %%
Hostgene_type(Human_miR_type_finalized_df,'miRNA_group', "miRNA_locations")
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1           17369         17436  miRNA_primary_transcript
# 1         chr1           30366         30503  miRNA_primary_transcript
# 2         chr1          187891        187958  miRNA_primary_transcript
# 3         chr1          632615        632685  miRNA_primary_transcript
# 4         chr1         1167104       1167198  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 1917      chrX       155457517     155457615  miRNA_primary_transcript
# 1918      chrY         1293918       1293992  miRNA_primary_transcript
# 1919      chrY         2609191       2609254  miRNA_primary_transcript
# 1920      chrY         4606120       4606228  miRNA_primary_transcript
# 1921      chrY        13479177      13479266  miRNA_primary_transcript
#
#             miR_Name miR_strand           miR_ID  \
# 0     hsa-mir-6859-1          -  Alias=MI0022705
# 1     hsa-mir-1302-2          +  Alias=MI0006363
# 2     hsa-mir-6859-2          -  Alias=MI0026420
# 3      hsa-mir-12136          -  Alias=MI0039740
# 4       hsa-mir-200b          +  Alias=MI0000342
# ...              ...        ...              ...
# 1917  hsa-mir-1184-3          +  Alias=MI0015972
# 1918  hsa-mir-3690-2          +  Alias=MI0023561
# 1919  hsa-mir-6089-2          +  Alias=MI0023563
# 1920    hsa-mir-9985          +  Alias=MI0032313
# 1921   hsa-mir-12120          +  Alias=MI0039722
#
#                                             miRNA_group miRNA_locations
# 0                                          intronic miR      intragenic
# 1                                            exonic miR      intragenic
# 2                                          intronic miR      intragenic
# 3                                      no host mRNA miR      intergenic
# 4                                            exonic miR      intragenic
# ...                                                 ...             ...
# 1917  partially overlapped with exons or opposite tr...      intragenic
# 1918  partially overlapped with exons or opposite tr...      intragenic
# 1919  partially overlapped with exons or opposite tr...      intragenic
# 1920                                   no host mRNA miR      intergenic
# 1921  partially overlapped with exons or opposite tr...      intragenic
#
# [1913 rows x 9 columns]

# %%
Human_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_group', 'miRNA_locations'],
#       dtype='object')

# %%
### Save this file
# already did Human_miR_type_finalized_df.drop_duplicates(subset=['miR_ID'],inplace=True)####drop any duplicates to remove isoforms

# %% [markdown]
# ## Pie charts

# %%
### Group them based the main_miRNA_type. That is, intragenic or intergenic
hg_loci=Human_miR_type_finalized_df.groupby(Human_miR_type_finalized_df['miRNA_locations']).size().reset_index(name='Count')

# %%
hg_loci
# Out:
#   miRNA_locations  Count
# 0      intergenic    394
# 1      intragenic   1519

# %%
hg_intergenic= hg_loci[hg_loci['miRNA_locations']=='intergenic'].sum()
hg_intragenic= hg_loci[hg_loci['miRNA_locations']=='intragenic'].sum()

# %%
#Human miR loci distribution pie Chart
labels = ['Intergenic', 'Intragenic']
sizes = [hg_intergenic['Count'],hg_intragenic['Count']]
colors = ['skyblue','lightcoral']
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of all human miRNome')
plt.savefig(f'{current_dir}/Pie_charts/Distribution of human miRNome(intergenic vs intragenic).eps')
plt.show()

# %%
### save the table
Human_miR_type_finalized_df.drop(columns=['miRNA_group']).to_excel(f"{current_dir}/MS_tables/Human_intra_and_inter_genic_miR_list.xlsx")
