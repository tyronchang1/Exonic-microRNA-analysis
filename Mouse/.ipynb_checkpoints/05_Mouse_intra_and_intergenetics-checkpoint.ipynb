# %% [markdown]
# ### Mouse intragenetic miRNAs(intronic/exonic miRs)

# %%
#bedtools will generate the overlapped exonic miR files--->mouse_exonic_miR_NCBI.tsv
import pandas as pd
import matplotlib.pyplot as plt
import os
current_dir=os.getcwd()
# /Users/tyronchang/Desktop/exonic-microrna-analysis/github/Mouse/MOuse_tsv_file/mouse_exonic_miR_NCBI.tsv

# %%
mRNA_miR_columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
Mouse_exonic_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_exonic_miR_NCBI.tsv', sep='\t',header=None, names=mRNA_miR_columns)

# %%
Mouse_exonic_miR_df
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  \
# 0             chr1            195033822          195037908
# 1             chr1            195033822          195037908
# 2             chr1            195033822          195037908
# 3             chr1            195033822          195037908
# 4             chr1            195033822          195037908
# ..             ...                  ...                ...
# 968          chr19             40894563           40894786
# 969          chr19             40894563           40894790
# 970          chr19             40894563           40894790
# 971          chr19             40894704           40894790
# 972          chr19             60774329           60774385
#
#      hostgene_cdsStarts  hostgene_cdsEnds hostgene_strand  exon_counts  \
# 0             195037908         195037908               +            8
# 1             195037908         195037908               +            8
# 2             195037908         195037908               +            8
# 3             195037908         195037908               +            8
# 4             195037908         195037908               +            8
# ..                  ...               ...             ...          ...
# 968            40911628          40916065               +            5
# 969            40911628          40916065               +            4
# 970            40911628          40916065               +            4
# 971            40911628          40916065               +            5
# 972            60774385          60774385               -            1
#
#      hostgene_TxStarts  hostgene_TxEnds  mature_host_mRNA_Length  \
# 0            195017398        195037908                     5195
# 1            195017398        195037908                     5195
# 2            195017398        195037908                     5195
# 3            195017398        195037908                     5195
# 4            195017398        195037908                     5195
# ..                 ...              ...                      ...
# 968           40894563         40917942                     6972
# 969           40894563         40917942                     6831
# 970           40894563         40917942                     6831
# 971           40894704         40917947                     6840
# 972           60774329         60774385                       56
#
#      hostgene_Name hostgene_NCBI_ID miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0    A330023F24Rik      NR_015566.2      chr1       195037040     195037120
# 1    A330023F24Rik      NR_015566.2      chr1       195037050     195037074
# 2    A330023F24Rik      NR_015566.2      chr1       195037091     195037113
# 3    A330023F24Rik      NR_015566.2      chr1       195037547     195037634
# 4    A330023F24Rik      NR_015566.2      chr1       195037562     195037583
# ..             ...              ...       ...             ...           ...
# 968        Zfp518a   XM_030251088.1     chr19        40894754      40894774
# 969        Zfp518a   XM_011247364.2     chr19        40894703      40894789
# 970        Zfp518a   XM_011247364.2     chr19        40894754      40894774
# 971        Zfp518a      NM_028319.1     chr19        40894754      40894774
# 972        Snora19      NR_034047.1     chr19        60774334      60774354
#
#                      miR_type               miR_Name miR_strand  \
# 0    miRNA_primary_transcript     Name=mmu-mir-29b-2          +
# 1                       miRNA  Name=mmu-miR-29b-2-5p          +
# 2                       miRNA    Name=mmu-miR-29b-3p          +
# 3    miRNA_primary_transcript       Name=mmu-mir-29c          +
# 4                       miRNA    Name=mmu-miR-29c-5p          +
# ..                        ...                    ...        ...
# 968                     miRNA      Name=mmu-miR-8092          +
# 969  miRNA_primary_transcript      Name=mmu-mir-8092          +
# 970                     miRNA      Name=mmu-miR-8092          +
# 971                     miRNA      Name=mmu-miR-8092          +
# 972                     miRNA   Name=mmu-miR-3084-3p          -
#
#                  miR_ID
# 0       Alias=MI0000712
# 1    Alias=MIMAT0017063
# 2    Alias=MIMAT0000127
# 3       Alias=MI0000577
# 4    Alias=MIMAT0004632
# ..                  ...
# 968  Alias=MIMAT0031393
# 969     Alias=MI0026019
# 970  Alias=MIMAT0031393
# 971  Alias=MIMAT0031393
# 972  Alias=MIMAT0014877
#
# [973 rows x 19 columns]

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.loc[Mouse_exonic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_exonic_miR_df['miRNA_group']='exonic miR'

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.drop_duplicates(subset=['miR_Name'])#### find the unique list

# %%
Mouse_exonic_miR_df.shape
# Out:
# (170, 8)

# %%
Mouse_exonic_miR_df.head()
# Out:
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1       195037040     195037120  miRNA_primary_transcript
# 3       chr1       195037547     195037634  miRNA_primary_transcript
# 6       chr1        20682769      20682887  miRNA_primary_transcript
# 9       chr1        86351981      86352127  miRNA_primary_transcript
# 11      chr1       134946234     134946299  miRNA_primary_transcript
#
#               miR_Name miR_strand           miR_ID miRNA_group
# 0   Name=mmu-mir-29b-2          +  Alias=MI0000712  exonic miR
# 3     Name=mmu-mir-29c          +  Alias=MI0000577  exonic miR
# 6    Name=mmu-mir-133b          +  Alias=MI0000821  exonic miR
# 9    Name=mmu-mir-3535          -  Alias=MI0026036  exonic miR
# 11  Name=mmu-mir-5104b          -  Alias=MI0040615  exonic miR

# %%
excel_file_path=f'{current_dir}/Mouse_excel_file'
csv_file_path=f'{current_dir}/Mouse_csv_file'

# %%
Mouse_exonic_miR_df.to_excel(f'{excel_file_path}/Mouse_exonic_miR_df_unique.xlsx',index=False)
Mouse_exonic_miR_df.to_csv(f'{csv_file_path}/Mouse_exonic_miR_df_unique.csv',index=False)
### save it as a unique exonic miRNA excel or csv file for later use
### this step is to use for mapping intronic and intergenetic miRNAs
### These files only have unique list with hose genes information but not gene functions

# %% [markdown]
# #### Mouse intronic microRNA files
# (Run this after running bedtools_intronic_miRs.sh)

# %%
mRNA_miR_columns_2=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
###all intronic micrornas
Mouse_intronic_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_intronic_miR_NCBI.tsv', sep='\t', header=None, names=mRNA_miR_columns_2)

# %%
Mouse_intronic_miR_df
# Out:
#       hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStarts  \
# 0               chr1          160219173        160792925           160224215
# 1               chr1          160219173        160792925           160224215
# 2               chr1          160219173        160792972           160224215
# 3               chr1          160219173        160792972           160224215
# 4               chr1          160219173        160792987           160224215
# ...              ...                ...              ...                 ...
# 11868          chr19           52991180         53015341            52991590
# 11869          chr19           52991180         53032644            52991590
# 11870          chr19           52991180         53032644            52991590
# 11871          chr19           52991182         53038570            52991590
# 11872          chr19           52991182         53038570            52991590
#
#        hostgene_cdsEnds hostgene_strand hostgene_Name hostgene_NCBI_ID  \
# 0             160740889               -      Rabgap1l   XM_006496877.3
# 1             160740889               -      Rabgap1l   XM_006496877.3
# 2             160740889               -      Rabgap1l   XM_006496876.2
# 3             160740889               -      Rabgap1l   XM_006496876.2
# 4             160739052               -      Rabgap1l   XM_006496878.4
# ...                 ...             ...           ...              ...
# 11868          53013471               -       Xpnpep1   XM_017318075.2
# 11869          53025375               -       Xpnpep1   XM_011247159.2
# 11870          53025375               -       Xpnpep1   XM_011247159.2
# 11871          53025375               -       Xpnpep1   NM_001374834.1
# 11872          53025375               -       Xpnpep1   NM_001374834.1
#
#       miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0          chr1       160295864     160295972  miRNA_primary_transcript
# 1          chr1       160295885     160295907                     miRNA
# 2          chr1       160295864     160295972  miRNA_primary_transcript
# 3          chr1       160295885     160295907                     miRNA
# 4          chr1       160295864     160295972  miRNA_primary_transcript
# ...         ...             ...           ...                       ...
# 11868     chr19        53010679      53010701                     miRNA
# 11869     chr19        53010656      53010756  miRNA_primary_transcript
# 11870     chr19        53010679      53010701                     miRNA
# 11871     chr19        53010656      53010756  miRNA_primary_transcript
# 11872     chr19        53010679      53010701                     miRNA
#
#                 miR_Name miR_strand              miR_ID
# 0      Name=mmu-mir-1927          -     Alias=MI0009914
# 1      Name=mmu-miR-1927          -  Alias=MIMAT0009390
# 2      Name=mmu-mir-1927          -     Alias=MI0009914
# 3      Name=mmu-miR-1927          -  Alias=MIMAT0009390
# 4      Name=mmu-mir-1927          -     Alias=MI0009914
# ...                  ...        ...                 ...
# 11868  Name=mmu-miR-6407          -  Alias=MIMAT0025160
# 11869  Name=mmu-mir-6407          -     Alias=MI0021944
# 11870  Name=mmu-miR-6407          -  Alias=MIMAT0025160
# 11871  Name=mmu-mir-6407          -     Alias=MI0021944
# 11872  Name=mmu-miR-6407          -  Alias=MIMAT0025160
#
# [11873 rows x 15 columns]

# %%
Mouse_intronic_miR_df=Mouse_intronic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Mouse_intronic_miR_df=Mouse_intronic_miR_df.loc[Mouse_intronic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_intronic_miR_df['miRNA_group']='intronic miR'

# %%
Mouse_intronic_miR_df.head()
# Out:
#   miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0      chr1       160295864     160295972  miRNA_primary_transcript
# 2      chr1       160295864     160295972  miRNA_primary_transcript
# 4      chr1       160295864     160295972  miRNA_primary_transcript
# 6      chr1       160295864     160295972  miRNA_primary_transcript
# 8      chr1       160295864     160295972  miRNA_primary_transcript
#
#             miR_Name miR_strand           miR_ID   miRNA_group
# 0  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 2  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 4  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 6  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 8  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR

# %%
Mouse_intronic_miR_df=Mouse_intronic_miR_df.drop_duplicates(subset=['miR_Name'])#### find the unique lists of miRNAs
Mouse_intronic_miR_df.to_excel(f'{excel_file_path}/mouse_intronic_miR_NCBI_unique.xlsx',index= False)
Mouse_intronic_miR_df.to_csv(f'{csv_file_path}/mouse_intronic_miR_NCBI_unique.csv',index= False)

# %%
Mouse_intronic_miR_df.shape
# Out:
# (599, 8)

# %% [markdown]
# ### Mouse intergenetic microRNA files

# %%
columns_4=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']

# %%
###all NO host mRNA micrornas
Mouse_no_host_mRNA_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_miR_no_hostmRNA_NCBI.tsv', sep='\t', header=None, names=columns_4)

# %%
Mouse_no_host_mRNA_miR_df=Mouse_no_host_mRNA_miR_df.loc[Mouse_no_host_mRNA_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_no_host_mRNA_miR_df['miRNA_group']='no host mRNA miR'

# %%
Mouse_no_host_mRNA_miR_df
# Out:
#     miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0        chr1        23272269      23272339  miRNA_primary_transcript
# 3        chr1        23291701      23291784  miRNA_primary_transcript
# 6        chr1        29421488      29421612  miRNA_primary_transcript
# 8        chr1        34433121      34433199  miRNA_primary_transcript
# 10       chr1        39186896      39186992  miRNA_primary_transcript
# ..        ...             ...           ...                       ...
# 667      chrX        88759474      88759553  miRNA_primary_transcript
# 669      chrX       105344282     105344369  miRNA_primary_transcript
# 672      chrX       106309826     106309935  miRNA_primary_transcript
# 674      chrX       136183245     136183360  miRNA_primary_transcript
# 676      chrX       144297790     144297899  miRNA_primary_transcript
#
#                 miR_Name miR_strand           miR_ID       miRNA_group
# 0       Name=mmu-mir-30a          +  Alias=MI0000144  no host mRNA miR
# 3     Name=mmu-mir-30c-2          +  Alias=MI0000548  no host mRNA miR
# 6      Name=mmu-mir-6342          +  Alias=MI0021870  no host mRNA miR
# 8      Name=mmu-mir-5103          -  Alias=MI0018011  no host mRNA miR
# 10     Name=mmu-mir-6349          -  Alias=MI0021877  no host mRNA miR
# ..                   ...        ...              ...               ...
# 667  Name=mmu-mir-1906-2          -  Alias=MI0015984  no host mRNA miR
# 669     Name=mmu-mir-384          -  Alias=MI0001146  no host mRNA miR
# 672    Name=mmu-mir-6382          +  Alias=MI0021913  no host mRNA miR
# 674    Name=mmu-mir-6383          +  Alias=MI0021914  no host mRNA miR
# 676   Name=mmu-mir-680-2          +  Alias=MI0004641  no host mRNA miR
#
# [258 rows x 8 columns]

# %%
Mouse_no_host_mRNA_miR_df=Mouse_no_host_mRNA_miR_df.drop_duplicates(subset=['miR_Name'])#### this will generate a  unique list of miRNAs
Mouse_no_host_mRNA_miR_df.to_csv(f"{csv_file_path}/mouse_miR_no_hostmRNA_NCBI_unique.csv",index=False)
Mouse_no_host_mRNA_miR_df.to_excel(f"{excel_file_path}/mouse_miR_no_hostmRNA_NCBI_unique.xlsx",index=False)

# %%
Mouse_no_host_mRNA_miR_df.shape
# Out:
# (258, 8)

# %% [markdown]
# #### Now generate a dataframe to classify all different types of miRNAs (e.g. exonic/intronic/no_host_genes).

# %%
Mouse_miR_type_df=pd.concat([Mouse_exonic_miR_df, Mouse_intronic_miR_df, Mouse_no_host_mRNA_miR_df], axis=0)

# %%
Mouse_miR_type_df=Mouse_miR_type_df.drop(columns=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_ID','miR_strand'])

# %%
Mouse_miR_type_df.head()
# Out:
#               miR_Name miRNA_group
# 0   Name=mmu-mir-29b-2  exonic miR
# 3     Name=mmu-mir-29c  exonic miR
# 6    Name=mmu-mir-133b  exonic miR
# 9    Name=mmu-mir-3535  exonic miR
# 11  Name=mmu-mir-5104b  exonic miR

# %%
Mouse_miR_type_df.shape
# Out:
# (1027, 2)

# %%
columns_3=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']

# %%
mouse_miR_miRBase_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mmu_finalized.tsv', sep='\t', header=None, names=columns_3)
### this file contains all micrornas including 3p and 5p mature miRNAs from the miRbase

# %%
mouse_miR_miRBase_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 1         chr1        12426016      12426038                     miRNA
# 2         chr1        20679010      20679082  miRNA_primary_transcript
# 3         chr1        20679017      20679039                     miRNA
# 4         chr1        20679055      20679076                     miRNA
# ...        ...             ...           ...                       ...
# 3332      chrX       151913214     151913321  miRNA_primary_transcript
# 3333      chrX       151913229     151913250                     miRNA
# 3334      chrX       151913287     151913308                     miRNA
# 3335      chrX       162874918     162874995  miRNA_primary_transcript
# 3336      chrX       162874920     162874937                     miRNA
#
#                  miR_Name miR_strand              miR_ID
# 0       Name=mmu-mir-6341          +     Alias=MI0021869
# 1       Name=mmu-miR-6341          +  Alias=MIMAT0025084
# 2        Name=mmu-mir-206          +     Alias=MI0000249
# 3     Name=mmu-miR-206-5p          +  Alias=MIMAT0017004
# 4     Name=mmu-miR-206-3p          +  Alias=MIMAT0000239
# ...                   ...        ...                 ...
# 3332      Name=mmu-mir-98          +     Alias=MI0000586
# 3333   Name=mmu-miR-98-5p          +  Alias=MIMAT0000545
# 3334   Name=mmu-miR-98-3p          +  Alias=MIMAT0017023
# 3335   Name=mmu-mir-3473a          -     Alias=MI0014706
# 3336   Name=mmu-miR-3473a          -  Alias=MIMAT0015645
#
# [3337 rows x 7 columns]

# %%
mouse_miR_miRBase_df=mouse_miR_miRBase_df.loc[mouse_miR_miRBase_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_miR_type_finalized_df=mouse_miR_miRBase_df.merge(Mouse_miR_type_df,on="miR_Name",how='left')
"""This will combine all the rest of miRNas that are niether intronic, exonic, nohost gene ones.
    In other words, these are partially overlappeed or antisense miRNAs.
"""
# Out:
# 'This will combine all the rest of miRNas that are niether intronic, exonic, nohost gene ones.\n    In other words, these are partially overlappeed or antisense miRNAs.\n'

# %%
Mouse_miR_type_finalized_df=Mouse_miR_type_finalized_df.loc[Mouse_miR_type_finalized_df['miR_type']=="miRNA_primary_transcript"]
Mouse_miR_type_finalized_df.head(50)
# Out:
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1        12425986      12426106  miRNA_primary_transcript
# 1       chr1        20679010      20679082  miRNA_primary_transcript
# 2       chr1        20682769      20682887  miRNA_primary_transcript
# 3       chr1        23272269      23272339  miRNA_primary_transcript
# 4       chr1        23291701      23291784  miRNA_primary_transcript
# 5       chr1        29421488      29421612  miRNA_primary_transcript
# 6       chr1        34117359      34117431  miRNA_primary_transcript
# 7       chr1        34433121      34433199  miRNA_primary_transcript
# 8       chr1        36144252      36144313  miRNA_primary_transcript
# 9       chr1        36348682      36348758  miRNA_primary_transcript
# 10      chr1        39186896      39186992  miRNA_primary_transcript
# 11      chr1        47467021      47467125  miRNA_primary_transcript
# 12      chr1        53849424      53849495  miRNA_primary_transcript
# 13      chr1        64042438      64042501  miRNA_primary_transcript
# 14      chr1        73855477      73855575  miRNA_primary_transcript
# 15      chr1        74206554      74206620  miRNA_primary_transcript
# 16      chr1        74394310      74394394  miRNA_primary_transcript
# 17      chr1        74900658      74900721  miRNA_primary_transcript
# 18      chr1        76509560      76509643  miRNA_primary_transcript
# 19      chr1        77496653      77496768  miRNA_primary_transcript
# 20      chr1        82131916      82132019  miRNA_primary_transcript
# 21      chr1        84218849      84218961  miRNA_primary_transcript
# 22      chr1        84695839      84695915  miRNA_primary_transcript
# 23      chr1        85751948      85752074  miRNA_primary_transcript
# 24      chr1        86351981      86352127  miRNA_primary_transcript
# 25      chr1        92464483      92464542  miRNA_primary_transcript
# 26      chr1        92850378      92850443  miRNA_primary_transcript
# 27      chr1        93274549      93274610  miRNA_primary_transcript
# 28      chr1        93346092      93346155  miRNA_primary_transcript
# 29      chr1        93352158      93352285  miRNA_primary_transcript
# 30      chr1       106546496     106546631  miRNA_primary_transcript
# 31      chr1       118954220     118954300  miRNA_primary_transcript
# 32      chr1       128202361     128202430  miRNA_primary_transcript
# 33      chr1       132198088     132198184  miRNA_primary_transcript
# 34      chr1       133726558     133726645  miRNA_primary_transcript
# 35      chr1       134946234     134946299  miRNA_primary_transcript
# 36      chr1       135454603     135454683  miRNA_primary_transcript
# 37      chr1       137966455     137966541  miRNA_primary_transcript
# 38      chr1       137966639     137966718  miRNA_primary_transcript
# 39      chr1       151442393     151442450  miRNA_primary_transcript
# 40      chr1       153899926     153900036  miRNA_primary_transcript
# 41      chr1       158505625     158505733  miRNA_primary_transcript
# 42      chr1       159340358     159340423  miRNA_primary_transcript
# 43      chr1       160295864     160295972  miRNA_primary_transcript
# 44      chr1       162217814     162217923  miRNA_primary_transcript
# 45      chr1       162223368     162223477  miRNA_primary_transcript
# 46      chr1       164217678     164217740  miRNA_primary_transcript
# 47      chr1       167290125     167290225  miRNA_primary_transcript
# 48      chr1       168490643     168490762  miRNA_primary_transcript
# 49      chr1       169018974     169019089  miRNA_primary_transcript
#
#                miR_Name miR_strand           miR_ID       miRNA_group
# 0     Name=mmu-mir-6341          +  Alias=MI0021869               NaN
# 1      Name=mmu-mir-206          +  Alias=MI0000249      intronic miR
# 2     Name=mmu-mir-133b          +  Alias=MI0000821        exonic miR
# 3      Name=mmu-mir-30a          +  Alias=MI0000144  no host mRNA miR
# 4    Name=mmu-mir-30c-2          +  Alias=MI0000548  no host mRNA miR
# 5     Name=mmu-mir-6342          +  Alias=MI0021870  no host mRNA miR
# 6     Name=mmu-mir-6896          +  Alias=MI0022743      intronic miR
# 7     Name=mmu-mir-5103          -  Alias=MI0018011  no host mRNA miR
# 8     Name=mmu-mir-6897          -  Alias=MI0022744      intronic miR
# 9     Name=mmu-mir-6898          -  Alias=MI0022745      intronic miR
# 10    Name=mmu-mir-6349          -  Alias=MI0021877  no host mRNA miR
# 11    Name=mmu-mir-6350          -  Alias=MI0021878  no host mRNA miR
# 12    Name=mmu-mir-7681          +  Alias=MI0025029               NaN
# 13    Name=mmu-mir-6899          -  Alias=MI0022746      intronic miR
# 14    Name=mmu-mir-6351          -  Alias=MI0021879      intronic miR
# 15    Name=mmu-mir-1928          -  Alias=MI0009917  no host mRNA miR
# 16     Name=mmu-mir-26b          +  Alias=MI0000575      intronic miR
# 17     Name=mmu-mir-375          -  Alias=MI0000792  no host mRNA miR
# 18    Name=mmu-mir-6343          +  Alias=MI0021871  no host mRNA miR
# 19    Name=mmu-mir-6352          -  Alias=MI0021880      intronic miR
# 20    Name=mmu-mir-6344          +  Alias=MI0021872  no host mRNA miR
# 21    Name=mmu-mir-6353          -  Alias=MI0021881      intronic miR
# 22    Name=mmu-mir-5126          +  Alias=MI0018038               NaN
# 23    Name=mmu-mir-8096          +  Alias=MI0026024  no host mRNA miR
# 24    Name=mmu-mir-3535          -  Alias=MI0026036        exonic miR
# 25    Name=mmu-mir-6900          -  Alias=MI0022747      intronic miR
# 26     Name=mmu-mir-149          +  Alias=MI0000171      intronic miR
# 27    Name=mmu-mir-6901          +  Alias=MI0022748               NaN
# 28    Name=mmu-mir-6902          +  Alias=MI0022749      intronic miR
# 29    Name=mmu-mir-6345          +  Alias=MI0021873      intronic miR
# 30   Name=mmu-mir-3473f          -  Alias=MI0026016      intronic miR
# 31    Name=mmu-mir-6346          +  Alias=MI0021874               NaN
# 32   Name=mmu-mir-128-1          +  Alias=MI0000155      intronic miR
# 33    Name=mmu-mir-135b          +  Alias=MI0000646      intronic miR
# 34    Name=mmu-mir-6903          -  Alias=MI0022750               NaN
# 35   Name=mmu-mir-5104b          -  Alias=MI0040615        exonic miR
# 36    Name=mmu-mir-1231          -  Alias=MI0019183      intronic miR
# 37  Name=mmu-mir-181a-1          +  Alias=MI0000697  no host mRNA miR
# 38  Name=mmu-mir-181b-1          +  Alias=MI0000723  no host mRNA miR
# 39    Name=mmu-mir-7682          +  Alias=MI0025030      intronic miR
# 40    Name=mmu-mir-8114          +  Alias=MI0026046               NaN
# 41     Name=mmu-mir-488          +  Alias=MI0004633      intronic miR
# 42   Name=mmu-mir-1843b          +  Alias=MI0016971        exonic miR
# 43    Name=mmu-mir-1927          -  Alias=MI0009914      intronic miR
# 44  Name=mmu-mir-199a-2          +  Alias=MI0000713        exonic miR
# 45     Name=mmu-mir-214          +  Alias=MI0000698        exonic miR
# 46   Name=mmu-mir-12178          +  Alias=MI0040616        exonic miR
# 47    Name=mmu-mir-6347          +  Alias=MI0021875  no host mRNA miR
# 48    Name=mmu-mir-6348          +  Alias=MI0021876               NaN
# 49    Name=mmu-mir-6354          -  Alias=MI0021882  no host mRNA miR

# %%
Mouse_miR_type_finalized_df.shape
# Out:
# (1229, 8)

# %% [markdown]
# ## Last step, here you will:
# ### 1) fill in the other empty cells with partially overlapped with exons
# ### 2) finalize the dataframe.

# %% [markdown]
# ### Mouse

# %%
Mouse_miR_type_finalized_df['miRNA_group']=Mouse_miR_type_finalized_df['miRNA_group'].fillna("partially overlapped with exons or opposite transcriptional units")

# %%
Mouse_miR_type_finalized_df['miR_Name']=Mouse_miR_type_finalized_df['miR_Name'].str.replace("Name=","")

# %%
Mouse_miR_type_finalized_df.drop_duplicates(subset=['miR_ID'],inplace=True)####drop any duplicates to remove isoforms

# %%
Mouse_miR_type_finalized_df.shape
# Out:
# (1226, 8)

# %%
Mouse_miR_type_finalized_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 1         chr1        20679010      20679082  miRNA_primary_transcript
# 2         chr1        20682769      20682887  miRNA_primary_transcript
# 3         chr1        23272269      23272339  miRNA_primary_transcript
# 4         chr1        23291701      23291784  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 1224      chrX       150547385     150547445  miRNA_primary_transcript
# 1225      chrX       151859562     151859637  miRNA_primary_transcript
# 1226      chrX       151912346     151912428  miRNA_primary_transcript
# 1227      chrX       151913214     151913321  miRNA_primary_transcript
# 1228      chrX       162874918     162874995  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID  \
# 0      mmu-mir-6341          +  Alias=MI0021869
# 1       mmu-mir-206          +  Alias=MI0000249
# 2      mmu-mir-133b          +  Alias=MI0000821
# 3       mmu-mir-30a          +  Alias=MI0000144
# 4     mmu-mir-30c-2          +  Alias=MI0000548
# ...             ...        ...              ...
# 1224   mmu-mir-3620          -  Alias=MI0025027
# 1225   mmu-mir-3113          +  Alias=MI0014111
# 1226   mmu-let-7f-2          +  Alias=MI0000563
# 1227     mmu-mir-98          +  Alias=MI0000586
# 1228  mmu-mir-3473a          -  Alias=MI0014706
#
#                                             miRNA_group
# 0     partially overlapped with exons or opposite tr...
# 1                                          intronic miR
# 2                                            exonic miR
# 3                                      no host mRNA miR
# 4                                      no host mRNA miR
# ...                                                 ...
# 1224  partially overlapped with exons or opposite tr...
# 1225                                         exonic miR
# 1226                                       intronic miR
# 1227                                       intronic miR
# 1228                                       intronic miR
#
# [1226 rows x 8 columns]

# %% [markdown]
# ## Plotting percentages of intergenetic and intragenetic miRNAs

# %%
Mouse_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_group'],
#       dtype='object')

# %%
def Hostgene_type(df, miRNAgroup,hostgenetype):
    """This function will assign miRNA to certain locations -intrageneic or intergenic"""
    df[hostgenetype]=df[miRNAgroup].apply(lambda x:"intergenic" if x=="no host mRNA miR" else "intragenic")
    return df

# %%
Hostgene_type(Mouse_miR_type_finalized_df,'miRNA_group', "miRNA_locations")
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 1         chr1        20679010      20679082  miRNA_primary_transcript
# 2         chr1        20682769      20682887  miRNA_primary_transcript
# 3         chr1        23272269      23272339  miRNA_primary_transcript
# 4         chr1        23291701      23291784  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 1224      chrX       150547385     150547445  miRNA_primary_transcript
# 1225      chrX       151859562     151859637  miRNA_primary_transcript
# 1226      chrX       151912346     151912428  miRNA_primary_transcript
# 1227      chrX       151913214     151913321  miRNA_primary_transcript
# 1228      chrX       162874918     162874995  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID  \
# 0      mmu-mir-6341          +  Alias=MI0021869
# 1       mmu-mir-206          +  Alias=MI0000249
# 2      mmu-mir-133b          +  Alias=MI0000821
# 3       mmu-mir-30a          +  Alias=MI0000144
# 4     mmu-mir-30c-2          +  Alias=MI0000548
# ...             ...        ...              ...
# 1224   mmu-mir-3620          -  Alias=MI0025027
# 1225   mmu-mir-3113          +  Alias=MI0014111
# 1226   mmu-let-7f-2          +  Alias=MI0000563
# 1227     mmu-mir-98          +  Alias=MI0000586
# 1228  mmu-mir-3473a          -  Alias=MI0014706
#
#                                             miRNA_group miRNA_locations
# 0     partially overlapped with exons or opposite tr...      intragenic
# 1                                          intronic miR      intragenic
# 2                                            exonic miR      intragenic
# 3                                      no host mRNA miR      intergenic
# 4                                      no host mRNA miR      intergenic
# ...                                                 ...             ...
# 1224  partially overlapped with exons or opposite tr...      intragenic
# 1225                                         exonic miR      intragenic
# 1226                                       intronic miR      intragenic
# 1227                                       intronic miR      intragenic
# 1228                                       intronic miR      intragenic
#
# [1226 rows x 9 columns]

# %%
Mouse_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_group', 'miRNA_locations'],
#       dtype='object')

# %%
### Save this file
# already did Mouse_miR_type_finalized_df.drop_duplicates(subset=['miR_ID'],inplace=True)####drop any duplicates to remove isoforms

# %% [markdown]
# ## Pie charts

# %%
### Group them based the main_miRNA_type. That is, intragenic or intergenic
mm_loci=Mouse_miR_type_finalized_df.groupby(Mouse_miR_type_finalized_df['miRNA_locations']).size().reset_index(name='Count')

# %%
mm_loci
# Out:
#   miRNA_locations  Count
# 0      intergenic    258
# 1      intragenic    968

# %%
mm_intergenic= mm_loci[mm_loci['miRNA_locations']=='intergenic'].sum()
mm_intragenic= mm_loci[mm_loci['miRNA_locations']=='intragenic'].sum()

# %%
#Mouse miR loci distribution pie Chart
labels = ['Intergenic', 'Intragenic']
sizes = [mm_intergenic['Count'],mm_intragenic['Count']]
colors = ['skyblue','lightcoral']
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of all mouse miRNome')
plt.savefig(f'{current_dir}/Pie_charts/Distribution of mouse miRNome(intergenic vs intragenic).eps')
plt.show()

# %%
### save the table
Mouse_miR_type_finalized_df.drop(columns=['miRNA_group',"miR_chrom","miR_exonStarts","miR_exonEnds"]).to_excel(f"{current_dir}/MS_tables/Mouse_intra_and_inter_genic_miR_list.xlsx",index=False)

# %%
Mouse_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_group', 'miRNA_locations'],
#       dtype='object')
