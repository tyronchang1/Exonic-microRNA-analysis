# %% [markdown]
# ### Mouse data ( 1st step of data cleaning: reshape column)

# %%
import pandas as pd
import os
import re
import matplotlib.pyplot as plt

# %%
current_dir=os.getcwd()

# %%
import import_ipynb
from utils.Data import MOUSE
# Out:
# importing Jupyter notebook from /Users/tyronchang/Desktop/exonic-microrna-analysis/github3/Mouse/utils/Data.ipynb

# %%
mouse=MOUSE(f'{current_dir}/UCSC_data_Mouse/mouse_genes_020324_NCBI.csv')

# %%
mouse.col_preprocess()

# %%
mouse.drop()

# %%
mouse.df.rename(columns={'name2':'gene_name'},inplace=True)
### Replace the column name

# %%
# Function to calculate mRNA length
def calculate_mrna_length(row):
    starts = list(map(int, row['exonStarts'].split(',')[:-1]))
    ends = list(map(int, row['exonEnds'].split(',')[:-1]))
    lengths = [end - start for start, end in zip(starts, ends)]
    return sum(lengths)

# Apply the function to each row and create a new column for mRNA length
mouse.df['mature_mRNA_Length'] = mouse.df.apply(calculate_mrna_length, axis=1)

# %%
mouse_gene_df=mouse.select(['chrom','exonStarts','exonCount',
                        'gene_name','name'])

# %%
mouse_gene_df['exonStarts']=mouse_gene_df['exonStarts'].str.replace(r',\Z','',regex=True)
### remove the comma by the end of the column prior to splitting the data

# %%
mouse_gene_df['exonStarts']=mouse_gene_df['exonStarts'].str.split(",")

# %%
mouse_gene_df=mouse_gene_df.explode('exonStarts')

# %%
mouse_gene_df=mouse_gene_df.reset_index(drop=True)

# %%
mouse_gene_df_2=mouse.select(['exonEnds','cdsStart','cdsEnd','strand','exonCount','txStart','txEnd','mature_mRNA_Length','gene_name','name'])

# %%
mouse_gene_df_2['exonEnds']=mouse_gene_df_2['exonEnds'].str.replace(r',\Z','',regex=True)
### remove the comma at the end of column

# %%
mouse_gene_df_2['exonEnds']=mouse_gene_df_2['exonEnds'].str.split(",")

# %%
mouse_gene_df_2=mouse_gene_df_2.explode('exonEnds')

# %%
mouse_gene_df_2.head(50).reset_index(drop=True)
# Out:
#      exonEnds   cdsStart     cdsEnd strand  exonCount    txStart      txEnd  \
# 0   134203590  134202950  134234733      -          2  134199214  134234856
# 1   134234856  134202950  134234733      -          2  134199214  134234856
# 2   134203590  134202950  134234355      -          2  134199214  134235457
# 3   134235457  134202950  134234355      -          2  134199214  134235457
# 4   134203590  134202950  134234355      -          3  134199214  134235457
# 5   134234446  134202950  134234355      -          3  134199214  134235457
# 6   134235457  134202950  134234355      -          3  134199214  134235457
# 7   134203590  134202950  134234355      -          3  134199214  134235457
# 8   134234412  134202950  134234355      -          3  134199214  134235457
# 9   134235457  134202950  134234355      -          3  134199214  134235457
# 10  134203590  134202950  134203505      -          2  134199214  134235457
# 11  134235457  134202950  134203505      -          2  134199214  134235457
# 12  134203590  134202950  134234355      -          3  134199218  134235053
# 13  134234412  134202950  134234355      -          3  134199218  134235053
# 14  134235053  134202950  134234355      -          3  134199218  134235053
# 15    8363633    8363474    8583258      -         13    8359738    8679095
# 16    8414313    8363474    8583258      -         13    8359738    8679095
# 17    8445119    8363474    8583258      -         13    8359738    8679095
# 18    8448132    8363474    8583258      -         13    8359738    8679095
# 19    8463465    8363474    8583258      -         13    8359738    8679095
# 20    8465553    8363474    8583258      -         13    8359738    8679095
# 21    8554763    8363474    8583258      -         13    8359738    8679095
# 22    8583334    8363474    8583258      -         13    8359738    8679095
# 23    8595542    8363474    8583258      -         13    8359738    8679095
# 24    8607152    8363474    8583258      -         13    8359738    8679095
# 25    8624881    8363474    8583258      -         13    8359738    8679095
# 26    8677848    8363474    8583258      -         13    8359738    8679095
# 27    8679095    8363474    8583258      -         13    8359738    8679095
# 28    8363633    8363474    8782800      -         16    8359738    8782893
# 29    8414313    8363474    8782800      -         16    8359738    8782893
# 30    8445119    8363474    8782800      -         16    8359738    8782893
# 31    8448132    8363474    8782800      -         16    8359738    8782893
# 32    8463465    8363474    8782800      -         16    8359738    8782893
# 33    8465553    8363474    8782800      -         16    8359738    8782893
# 34    8554763    8363474    8782800      -         16    8359738    8782893
# 35    8583334    8363474    8782800      -         16    8359738    8782893
# 36    8595542    8363474    8782800      -         16    8359738    8782893
# 37    8607152    8363474    8782800      -         16    8359738    8782893
# 38    8624881    8363474    8782800      -         16    8359738    8782893
# 39    8677848    8363474    8782800      -         16    8359738    8782893
# 40    8677980    8363474    8782800      -         16    8359738    8782893
# 41    8679130    8363474    8782800      -         16    8359738    8782893
# 42    8682029    8363474    8782800      -         16    8359738    8782893
# 43    8782893    8363474    8782800      -         16    8359738    8782893
# 44    8363633    8363474    8803943      -         20    8359738    9250481
# 45    8414313    8363474    8803943      -         20    8359738    9250481
# 46    8445119    8363474    8803943      -         20    8359738    9250481
# 47    8448132    8363474    8803943      -         20    8359738    9250481
# 48    8463465    8363474    8803943      -         20    8359738    9250481
# 49    8465553    8363474    8803943      -         20    8359738    9250481
#
#     mature_mRNA_Length gene_name            name
# 0                 4570    Adora1  NM_001291928.1
# 1                 4570    Adora1  NM_001291928.1
# 2                 5819    Adora1  NM_001008533.3
# 3                 5819    Adora1  NM_001008533.3
# 4                 5038    Adora1  NM_001282945.1
# 5                 5038    Adora1  NM_001282945.1
# 6                 5038    Adora1  NM_001282945.1
# 7                 5004    Adora1  NM_001039510.2
# 8                 5004    Adora1  NM_001039510.2
# 9                 5004    Adora1  NM_001039510.2
# 10                4606    Adora1  NM_001291930.1
# 11                4606    Adora1  NM_001291930.1
# 12                5161    Adora1  XM_006529079.3
# 13                5161    Adora1  XM_006529079.3
# 14                5161    Adora1  XM_006529079.3
# 15                4992     Sntg1  XM_017312325.1
# 16                4992     Sntg1  XM_017312325.1
# 17                4992     Sntg1  XM_017312325.1
# 18                4992     Sntg1  XM_017312325.1
# 19                4992     Sntg1  XM_017312325.1
# 20                4992     Sntg1  XM_017312325.1
# 21                4992     Sntg1  XM_017312325.1
# 22                4992     Sntg1  XM_017312325.1
# 23                4992     Sntg1  XM_017312325.1
# 24                4992     Sntg1  XM_017312325.1
# 25                4992     Sntg1  XM_017312325.1
# 26                4992     Sntg1  XM_017312325.1
# 27                4992     Sntg1  XM_017312325.1
# 28                5239     Sntg1  XM_030242990.1
# 29                5239     Sntg1  XM_030242990.1
# 30                5239     Sntg1  XM_030242990.1
# 31                5239     Sntg1  XM_030242990.1
# 32                5239     Sntg1  XM_030242990.1
# 33                5239     Sntg1  XM_030242990.1
# 34                5239     Sntg1  XM_030242990.1
# 35                5239     Sntg1  XM_030242990.1
# 36                5239     Sntg1  XM_030242990.1
# 37                5239     Sntg1  XM_030242990.1
# 38                5239     Sntg1  XM_030242990.1
# 39                5239     Sntg1  XM_030242990.1
# 40                5239     Sntg1  XM_030242990.1
# 41                5239     Sntg1  XM_030242990.1
# 42                5239     Sntg1  XM_030242990.1
# 43                5239     Sntg1  XM_030242990.1
# 44                6626     Sntg1  XM_017312320.2
# 45                6626     Sntg1  XM_017312320.2
# 46                6626     Sntg1  XM_017312320.2
# 47                6626     Sntg1  XM_017312320.2
# 48                6626     Sntg1  XM_017312320.2
# 49                6626     Sntg1  XM_017312320.2

# %%
mouse_gene_df_2.rename(columns={'gene_name':'Name','exonCount':'exon_count','name':'ID'},inplace=True)

# %%
mouse_gene_df_2 = mouse_gene_df_2.reset_index(drop=True)

# %% [markdown]
# ### Concatanate the dataframe (Reshape the dataframe) and remove all miRNA dataset

# %%
finalized_mouse_gene_df=pd.concat([mouse_gene_df,mouse_gene_df_2], axis=1)#### This file contains all mouse genes!

# %%
finalized_mouse_gene_df.shape
# Out:
# (1385818, 15)

# %%
finalized_mouse_gene_df.columns
# Out:
# Index(['chrom', 'exonStarts', 'exonCount', 'gene_name', 'name', 'exonEnds',
#        'cdsStart', 'cdsEnd', 'strand', 'exon_count', 'txStart', 'txEnd',
#        'mature_mRNA_Length', 'Name', 'ID'],
#       dtype='object')

# %%
finalized_mouse_gene_df.drop(columns=['exonCount','gene_name','name'],inplace=True)

# %%
finalized_mouse_gene_df.columns
# Out:
# Index(['chrom', 'exonStarts', 'exonEnds', 'cdsStart', 'cdsEnd', 'strand',
#        'exon_count', 'txStart', 'txEnd', 'mature_mRNA_Length', 'Name', 'ID'],
#       dtype='object')

# %%
####This regex only extract microRNA but not lncRNA.
mouse_p=r'^Mir\d+(-\d+)*$|^Mir\d+[a-z](-\d+)*$|^Mir\d+[a-z]([a-z]|\d)*$(?<!hg)$|^Mirlet\d[a-z]-*\d*$(?<!hg)$'

# %%
mouse_all_genes_no_miR_df=finalized_mouse_gene_df.loc[~finalized_mouse_gene_df['Name'].str.contains(
mouse_p, flags=re.I,regex=True)]####Remove all miR from the data. So this file has all mouse genes except for miRNAs
# Out:
# /var/folders/hz/4x5ldhv54fscy_nw6y5dbf2m0000gn/T/ipykernel_13200/1856401095.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mouse_all_genes_no_miR_df=finalized_mouse_gene_df.loc[~finalized_mouse_gene_df['Name'].str.contains(

# %%
mouse_all_genes_no_miR_df.shape
# Out:
# (1384536, 12)

# %%
mouse_all_genes_no_miR_df.columns
# Out:
# Index(['chrom', 'exonStarts', 'exonEnds', 'cdsStart', 'cdsEnd', 'strand',
#        'exon_count', 'txStart', 'txEnd', 'mature_mRNA_Length', 'Name', 'ID'],
#       dtype='object')

# %%
### save the file
mouse_all_genes_no_miR_df.to_csv(f'{current_dir}/Mouse_bash_script/mouse_all_genes_no_miR_df_NCBI.tsv',sep='\t',index=False)

# %% [markdown]
# ### Extract miRNA data

# %%
##extract mouse miRs
mouse_df_miR=finalized_mouse_gene_df.loc[finalized_mouse_gene_df['Name'].str.contains(mouse_p,flags=re.I,regex=True)]
# Out:
# /var/folders/hz/4x5ldhv54fscy_nw6y5dbf2m0000gn/T/ipykernel_13200/3488575663.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mouse_df_miR=finalized_mouse_gene_df.loc[finalized_mouse_gene_df['Name'].str.contains(mouse_p,flags=re.I,regex=True)]

# %%
mouse_df_miR.shape ### this dataset do not have lncRNA (e.g. miR-210HG) It has only miRNAs
# Out:
# (1282, 12)

# %%
mouse_df_miR.head(5)
# Out:
#       chrom exonStarts  exonEnds  cdsStart    cdsEnd strand  exon_count  \
# 56853  chr1   12425985  12426106  12426106  12426106      +           1
# 57475  chr1   20679009  20679082  20679082  20679082      +           1
# 57476  chr1   20682768  20682887  20682887  20682887      +           1
# 57636  chr1   23272268  23272339  23272339  23272339      +           1
# 57637  chr1   23291700  23291784  23291784  23291784      +           1
#
#         txStart     txEnd  mature_mRNA_Length      Name           ID
# 56853  12425985  12426106                 121   Mir6341  NR_105759.1
# 57475  20679009  20679082                  73    Mir206  NR_029593.1
# 57476  20682768  20682887                 119   Mir133b  NR_029902.1
# 57636  23272268  23272339                  71    Mir30a  NR_029533.1
# 57637  23291700  23291784                  84  Mir30c-2  NR_029717.1

# %%
###save the file for microRNA dataset
mouse_df_miR.to_csv(f'{current_dir}/Mouse_bash_script/df_mousemiR_NCBI.tsv',sep="\t",index=False)

# %% [markdown]
# ## 6. Before you run bedtools_intronic_miRs.sh, reshape the dataframe first and map intronic miRNA with the following steps
#
# The reason for reshaping the dataframe are the following:
# * We need to use txStart, txEnd coordinates instead of exon coordinates to find intronic miRNAs.
# * The finalized tsv files will be "mouse_all_genes_no_miR_df_TX_loc_NCBI.tsv".
# * We will use this new tsv file to overlap the coordinates of miR to map all the intronic miRNAs.
# * Remember the new file has txStart and txEnd locations instead of exon locations.
# * bedtools_intronic_miRs.sh will also map the rest of miRNAs that don't have mRNA host genes.

# %%
# Out:
#   hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0           chr1            195033822          195037908          195037908
# 1           chr1            195033822          195037908          195037908
# 2           chr1            195033822          195037908          195037908
# 3           chr1            195033822          195037908          195037908
# 4           chr1            195033822          195037908          195037908
#
#    hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0        195037908               +                    8          195017398
# 1        195037908               +                    8          195017398
# 2        195037908               +                    8          195017398
# 3        195037908               +                    8          195017398
# 4        195037908               +                    8          195017398
#
#    hostgene_txEnds  mature_host_mRNA_Length  hostgene_Name hostgene_NCBI_ID  \
# 0        195037908                     5195  A330023F24Rik      NR_015566.2
# 1        195037908                     5195  A330023F24Rik      NR_015566.2
# 2        195037908                     5195  A330023F24Rik      NR_015566.2
# 3        195037908                     5195  A330023F24Rik      NR_015566.2
# 4        195037908                     5195  A330023F24Rik      NR_015566.2
#
#   miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0      chr1       195037040     195037120  miRNA_primary_transcript
# 1      chr1       195037050     195037074                     miRNA
# 2      chr1       195037091     195037113                     miRNA
# 3      chr1       195037547     195037634  miRNA_primary_transcript
# 4      chr1       195037562     195037583                     miRNA
#
#                 miR_Name miR_strand              miR_ID
# 0     Name=mmu-mir-29b-2          +     Alias=MI0000712
# 1  Name=mmu-miR-29b-2-5p          +  Alias=MIMAT0017063
# 2    Name=mmu-miR-29b-3p          +  Alias=MIMAT0000127
# 3       Name=mmu-mir-29c          +     Alias=MI0000577
# 4    Name=mmu-miR-29c-5p          +  Alias=MIMAT0004632

# %%
mouse_exonicmiR_df=mouse_exonicmiR_df.loc[mouse_exonicmiR_df['miR_type']=="miRNA_primary_transcript"]

# %%
mouse_exonicmiR_df.drop(columns=['miR_ID'],inplace=True)

# %%
mouse_exonicmiR_df.head()
# Out:
#    hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0            chr1            195033822          195037908          195037908
# 3            chr1            195033822          195037908          195037908
# 6            chr1             20682712           20682958           20682958
# 9            chr1             86351980           86352127           86352127
# 11           chr1            134946233          134946299          134946299
#
#     hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0         195037908               +                    8          195017398
# 3         195037908               +                    8          195017398
# 6          20682958               +                    3           20669881
# 9          86352127               -                    1           86351980
# 11        134946299               -                    1          134946233
#
#     hostgene_txEnds  mature_host_mRNA_Length  hostgene_Name hostgene_NCBI_ID  \
# 0         195037908                     5195  A330023F24Rik      NR_015566.2
# 3         195037908                     5195  A330023F24Rik      NR_015566.2
# 6          20682958                      521        Lincmd1      NR_131249.1
# 9          86352127                      147        Gm24148      NR_106184.1
# 11        134946299                       66        Gm51265      NR_162775.1
#
#    miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0       chr1       195037040     195037120  miRNA_primary_transcript
# 3       chr1       195037547     195037634  miRNA_primary_transcript
# 6       chr1        20682769      20682887  miRNA_primary_transcript
# 9       chr1        86351981      86352127  miRNA_primary_transcript
# 11      chr1       134946234     134946299  miRNA_primary_transcript
#
#               miR_Name miR_strand
# 0   Name=mmu-mir-29b-2          +
# 3     Name=mmu-mir-29c          +
# 6    Name=mmu-mir-133b          +
# 9    Name=mmu-mir-3535          -
# 11  Name=mmu-mir-5104b          -

# %%
#Change string values in the columns of exonic miR files

# Reset the index
mouse_exonicmiR_df = mouse_exonicmiR_df.reset_index(drop=True)

# Create a new DataFrame with the updated "miR_name" column
new_df_2 = pd.DataFrame({"miR_name": mouse_exonicmiR_df["miR_Name"].str.replace("Name=", "")})

# Concatenate the new DataFrame with the remaining columns from the original DataFrame
mouse_exonicmiR_df.insert(12,"miR_name", new_df_2['miR_name'])
mouse_exonicmiR_df.drop(columns=["miR_Name"],inplace=True)

# %%
mouse_exonicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0           chr1            195033822          195037908          195037908
# 1           chr1            195033822          195037908          195037908
# 2           chr1             20682712           20682958           20682958
# 3           chr1             86351980           86352127           86352127
# 4           chr1            134946233          134946299          134946299
#
#    hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0        195037908               +                    8          195017398
# 1        195037908               +                    8          195017398
# 2         20682958               +                    3           20669881
# 3         86352127               -                    1           86351980
# 4        134946299               -                    1          134946233
#
#    hostgene_txEnds  mature_host_mRNA_Length  hostgene_Name hostgene_NCBI_ID  \
# 0        195037908                     5195  A330023F24Rik      NR_015566.2
# 1        195037908                     5195  A330023F24Rik      NR_015566.2
# 2         20682958                      521        Lincmd1      NR_131249.1
# 3         86352127                      147        Gm24148      NR_106184.1
# 4        134946299                       66        Gm51265      NR_162775.1
#
#         miR_name miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0  mmu-mir-29b-2      chr1       195037040     195037120
# 1    mmu-mir-29c      chr1       195037547     195037634
# 2   mmu-mir-133b      chr1        20682769      20682887
# 3   mmu-mir-3535      chr1        86351981      86352127
# 4  mmu-mir-5104b      chr1       134946234     134946299
#
#                    miR_type miR_strand
# 0  miRNA_primary_transcript          +
# 1  miRNA_primary_transcript          +
# 2  miRNA_primary_transcript          +
# 3  miRNA_primary_transcript          -
# 4  miRNA_primary_transcript          -

# %%
mouse_exonicmiR_df.shape
# Out:
# (339, 18)

# %%
csv_file_path=f'{current_dir}/Mouse_csv_file'

# %%
#save the mouse exonic data (tsv) file as a csv file
mouse_exonicmiR_df.to_csv(f'{csv_file_path}/mouse_exonic_miR_NCBI.csv',index=False)
#convert to csv file

# %% [markdown]
# ## 6. Before you run bedtools_intronic_miRs.sh, reshape the dataframe first and map intronic miRNA with the following steps
#
# The reason for reshaping the dataframe are the following:
# * We need to use txStart, txEnd coordinates instead of exon coordinates to find intronic miRNAs.
# * The finalized tsv files will be "mouse_all_genes_no_miR_df_TX_loc_NCBI.tsv".
# * We will use this new tsv file to overlap the coordinates of miR to map all the intronic miRNAs.
# * Remember the new file has txStart and txEnd locations instead of exon locations.
# * bedtools_intronic_miRs.sh will also map the rest of miRNAs that don't have mRNA host genes.

# %% [markdown]
# ### Mouse

# %%
mouse_gene_df_tx=mouse.select(['chrom','txStart','txEnd','cdsStart','cdsEnd','strand',
                        'gene_name','name'])
#### here you will select transcription start and end sites

# %%
mouse_gene_df_tx.rename(columns={'gene_name':'Name','name':'ID'},inplace=True)

# %%
mouse_all_genes_no_miR_df_TX_loc=mouse_gene_df_tx.loc[~mouse_gene_df_tx['Name'].str.contains(
mouse_p, flags=re.I,regex=True)]####Remove all miR from the data.
# Out:
# /var/folders/hc/mc3kqq154077vn1n8slj6jsr0000gr/T/ipykernel_15312/3585549947.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mouse_all_genes_no_miR_df_TX_loc=mouse_gene_df_tx.loc[~mouse_gene_df_tx['Name'].str.contains(

# %%
mouse_all_genes_no_miR_df_TX_loc.to_csv(f'{current_dir}/Mouse_tsv_file/mouse_all_genes_no_miR_df_TX_loc_NCBI.tsv',sep='\t',index=False)

# %%
##### use this file to find intronic miRNAs, by running bedtools_mouse_intronic_miR.sh

# %%
#### Run bedtools_human_nonexonic_miR.sh and then bedtools_mouse_intronic_miR.sh

# %% [markdown]
# ### 7. Use Gene_func file to add additional columns to the dataframe (7th step).
# This new column will have a new column called gene type. Bascially this new dataframe will tell you if the host gene is a protein or non-coding RNA.

# %%
from Gene_func import Gene_type
from Gene_func import Cal_mRNA_length
# Out:
# importing Jupyter notebook from Gene_func.ipynb

# %%
Gene_type(mouse_exonicmiR_df,'hostgene_cdsStart','hostgene_cdsEnd','gene_type')

# %%
mouse_exonicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0           chr1            195033822          195037908          195037908
# 1           chr1            195033822          195037908          195037908
# 2           chr1             20682712           20682958           20682958
# 3           chr1             86351980           86352127           86352127
# 4           chr1            134946233          134946299          134946299
#
#    hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0        195037908               +                    8          195017398
# 1        195037908               +                    8          195017398
# 2         20682958               +                    3           20669881
# 3         86352127               -                    1           86351980
# 4        134946299               -                    1          134946233
#
#    hostgene_txEnds  mature_host_mRNA_Length  hostgene_Name hostgene_NCBI_ID  \
# 0        195037908                     5195  A330023F24Rik      NR_015566.2
# 1        195037908                     5195  A330023F24Rik      NR_015566.2
# 2         20682958                      521        Lincmd1      NR_131249.1
# 3         86352127                      147        Gm24148      NR_106184.1
# 4        134946299                       66        Gm51265      NR_162775.1
#
#         miR_name miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0  mmu-mir-29b-2      chr1       195037040     195037120
# 1    mmu-mir-29c      chr1       195037547     195037634
# 2   mmu-mir-133b      chr1        20682769      20682887
# 3   mmu-mir-3535      chr1        86351981      86352127
# 4  mmu-mir-5104b      chr1       134946234     134946299
#
#                    miR_type miR_strand        gene_type
# 0  miRNA_primary_transcript          +  non-coding gene
# 1  miRNA_primary_transcript          +  non-coding gene
# 2  miRNA_primary_transcript          +  non-coding gene
# 3  miRNA_primary_transcript          -  non-coding gene
# 4  miRNA_primary_transcript          -  non-coding gene

# %%
Cal_mRNA_length(mouse_exonicmiR_df,'hostgene_txStarts','hostgene_txEnds','hostgene_cdsStart','hostgene_cdsEnd','gene_type','pre_mRNA_length')

# %%
mouse_exonicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0           chr1            195033822          195037908          195037908
# 1           chr1            195033822          195037908          195037908
# 2           chr1             20682712           20682958           20682958
# 3           chr1             86351980           86352127           86352127
# 4           chr1            134946233          134946299          134946299
#
#    hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0        195037908               +                    8          195017398
# 1        195037908               +                    8          195017398
# 2         20682958               +                    3           20669881
# 3         86352127               -                    1           86351980
# 4        134946299               -                    1          134946233
#
#    hostgene_txEnds  mature_host_mRNA_Length  hostgene_Name hostgene_NCBI_ID  \
# 0        195037908                     5195  A330023F24Rik      NR_015566.2
# 1        195037908                     5195  A330023F24Rik      NR_015566.2
# 2         20682958                      521        Lincmd1      NR_131249.1
# 3         86352127                      147        Gm24148      NR_106184.1
# 4        134946299                       66        Gm51265      NR_162775.1
#
#         miR_name miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0  mmu-mir-29b-2      chr1       195037040     195037120
# 1    mmu-mir-29c      chr1       195037547     195037634
# 2   mmu-mir-133b      chr1        20682769      20682887
# 3   mmu-mir-3535      chr1        86351981      86352127
# 4  mmu-mir-5104b      chr1       134946234     134946299
#
#                    miR_type miR_strand        gene_type  pre_mRNA_length
# 0  miRNA_primary_transcript          +  non-coding gene          20510.0
# 1  miRNA_primary_transcript          +  non-coding gene          20510.0
# 2  miRNA_primary_transcript          +  non-coding gene          13077.0
# 3  miRNA_primary_transcript          -  non-coding gene            147.0
# 4  miRNA_primary_transcript          -  non-coding gene             66.0

# %%
### save it as a csv file
mouse_exonicmiR_df.to_csv(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR(gene_type)_NCBI.csv',index=False)

# %% [markdown]
# ## Intronic miRNAs organization

# %% [markdown]
# #### Mouse

# %%
#bedtools will generate the overlapped intronic miR files


columns_2=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 'hostgene_cdsStart', 'hostgene_cdsEnd'
         , 'hostgene_strand',
       'hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type'
         , 'miR_Name',
       'miR_strand', 'miR_ID']

# %%
mouse_intronicmiR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_intronic_miR_NCBI.tsv', sep='\t', header=None, names=columns_2)

# %%
mouse_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          160219173        160792925          160224215
# 1           chr1          160219173        160792925          160224215
# 2           chr1          160219173        160792972          160224215
# 3           chr1          160219173        160792972          160224215
# 4           chr1          160219173        160792987          160224215
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        160740889               -      Rabgap1l   XM_006496877.3      chr1
# 1        160740889               -      Rabgap1l   XM_006496877.3      chr1
# 2        160740889               -      Rabgap1l   XM_006496876.2      chr1
# 3        160740889               -      Rabgap1l   XM_006496876.2      chr1
# 4        160739052               -      Rabgap1l   XM_006496878.4      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type           miR_Name  \
# 0       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 1       160295885     160295907                     miRNA  Name=mmu-miR-1927
# 2       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 3       160295885     160295907                     miRNA  Name=mmu-miR-1927
# 4       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
#
#   miR_strand              miR_ID
# 0          -     Alias=MI0009914
# 1          -  Alias=MIMAT0009390
# 2          -     Alias=MI0009914
# 3          -  Alias=MIMAT0009390
# 4          -     Alias=MI0009914

# %%
mouse_intronicmiR_df=mouse_intronicmiR_df.loc[mouse_intronicmiR_df['miR_type']=="miRNA_primary_transcript"]

# %%
mouse_intronicmiR_df.drop(columns=['miR_ID'],inplace=True)

# %%
mouse_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          160219173        160792925          160224215
# 2           chr1          160219173        160792972          160224215
# 4           chr1          160219173        160792987          160224215
# 6           chr1          160219173        160793476          160224215
# 8           chr1          160256571        160792938          160257251
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        160740889               -      Rabgap1l   XM_006496877.3      chr1
# 2        160740889               -      Rabgap1l   XM_006496876.2      chr1
# 4        160739052               -      Rabgap1l   XM_006496878.4      chr1
# 6        160740889               -      Rabgap1l   XM_006496875.1      chr1
# 8        160740889               -      Rabgap1l      NM_013862.5      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type           miR_Name  \
# 0       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 2       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 4       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 6       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
# 8       160295864     160295972  miRNA_primary_transcript  Name=mmu-mir-1927
#
#   miR_strand
# 0          -
# 2          -
# 4          -
# 6          -
# 8          -

# %%
mouse_intronicmiR_df.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_exonStarts',
#        'miR_exonEnds', 'miR_type', 'miR_Name', 'miR_strand'],
#       dtype='object')

# %%
#Change string values in the columns of exonic miR files

# Reset the index
mouse_intronicmiR_df= mouse_intronicmiR_df.reset_index(drop=True)

# Create a new DataFrame with the updated "miR_name" column
mm_intron_df= pd.DataFrame({"miR_name": mouse_intronicmiR_df["miR_Name"].str.replace("Name=", "")})

# Concatenate the new DataFrame with the remaining columns from the original DataFrame
mouse_intronicmiR_df.insert(12,"miR_name",mm_intron_df['miR_name'])
mouse_intronicmiR_df.drop(columns=["miR_Name"],inplace=True)

# %%
mouse_intronicmiR_df.shape
# Out:
# (4019, 14)

# %%
#save it as a csv file
mouse_intronicmiR_df.to_csv(f'{csv_file_path}/mouse_intronic_miR_NCBI.csv',index=False)#convert to csv file

# %%
Gene_type(mouse_intronicmiR_df,'hostgene_cdsStart','hostgene_cdsEnd','gene_type')

# %%
mouse_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          160219173        160792925          160224215
# 1           chr1          160219173        160792972          160224215
# 2           chr1          160219173        160792987          160224215
# 3           chr1          160219173        160793476          160224215
# 4           chr1          160256571        160792938          160257251
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        160740889               -      Rabgap1l   XM_006496877.3      chr1
# 1        160740889               -      Rabgap1l   XM_006496876.2      chr1
# 2        160739052               -      Rabgap1l   XM_006496878.4      chr1
# 3        160740889               -      Rabgap1l   XM_006496875.1      chr1
# 4        160740889               -      Rabgap1l      NM_013862.5      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type      miR_name  \
# 0       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 1       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 2       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 3       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 4       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
#
#   miR_strand            gene_type
# 0          -  protein-coding gene
# 1          -  protein-coding gene
# 2          -  protein-coding gene
# 3          -  protein-coding gene
# 4          -  protein-coding gene

# %%
Cal_mRNA_length(mouse_intronicmiR_df,'hostgene_TxStarts','hostgene_TxEnds','hostgene_cdsStart','hostgene_cdsEnd','gene_type','pre_mRNA_length')

# %%
mouse_intronicmiR_df.head()
# Out:
#   hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStart  \
# 0           chr1          160219173        160792925          160224215
# 1           chr1          160219173        160792972          160224215
# 2           chr1          160219173        160792987          160224215
# 3           chr1          160219173        160793476          160224215
# 4           chr1          160256571        160792938          160257251
#
#    hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID miR_chrom  \
# 0        160740889               -      Rabgap1l   XM_006496877.3      chr1
# 1        160740889               -      Rabgap1l   XM_006496876.2      chr1
# 2        160739052               -      Rabgap1l   XM_006496878.4      chr1
# 3        160740889               -      Rabgap1l   XM_006496875.1      chr1
# 4        160740889               -      Rabgap1l      NM_013862.5      chr1
#
#    miR_exonStarts  miR_exonEnds                  miR_type      miR_name  \
# 0       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 1       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 2       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 3       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
# 4       160295864     160295972  miRNA_primary_transcript  mmu-mir-1927
#
#   miR_strand            gene_type  pre_mRNA_length
# 0          -  protein-coding gene         573752.0
# 1          -  protein-coding gene         573799.0
# 2          -  protein-coding gene         573814.0
# 3          -  protein-coding gene         574303.0
# 4          -  protein-coding gene         536367.0

# %%
mouse_intronicmiR_df.to_csv(f'{current_dir}/Mouse_tsv_file/mouse_intronic_miR(gene_type)_NCBI.csv',index=False)

# %% [markdown]
# ## Map percentages of intronic, exonic, other microRNAs using bedtools
#
# * This step is also run after bedtools files are run (bedtools_mouse_nonexonic_miR.sh)

# %% [markdown]
# ### Mouse intragenetic miRNAs(intronic/exonic miRs)

# %%
mRNA_miR_columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
Mouse_exonic_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_exonic_miR_NCBI.tsv', sep='\t', header=None, names=mRNA_miR_columns)

# %%
Mouse_exonic_miR_df
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  \
# 0             chr1            195033822          195037908
# 1             chr1            195033822          195037908
# 2             chr1            195033822          195037908
# 3             chr1            195033822          195037908
# 4             chr1            195033822          195037908
# ..             ...                  ...                ...
# 968          chr19             40894563           40894786
# 969          chr19             40894563           40894790
# 970          chr19             40894563           40894790
# 971          chr19             40894704           40894790
# 972          chr19             60774329           60774385
#
#      hostgene_cdsStarts  hostgene_cdsEnds hostgene_strand  exon_counts  \
# 0             195037908         195037908               +            8
# 1             195037908         195037908               +            8
# 2             195037908         195037908               +            8
# 3             195037908         195037908               +            8
# 4             195037908         195037908               +            8
# ..                  ...               ...             ...          ...
# 968            40911628          40916065               +            5
# 969            40911628          40916065               +            4
# 970            40911628          40916065               +            4
# 971            40911628          40916065               +            5
# 972            60774385          60774385               -            1
#
#      hostgene_TxStarts  hostgene_TxEnds  mature_host_mRNA_Length  \
# 0            195017398        195037908                     5195
# 1            195017398        195037908                     5195
# 2            195017398        195037908                     5195
# 3            195017398        195037908                     5195
# 4            195017398        195037908                     5195
# ..                 ...              ...                      ...
# 968           40894563         40917942                     6972
# 969           40894563         40917942                     6831
# 970           40894563         40917942                     6831
# 971           40894704         40917947                     6840
# 972           60774329         60774385                       56
#
#      hostgene_Name hostgene_NCBI_ID miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0    A330023F24Rik      NR_015566.2      chr1       195037040     195037120
# 1    A330023F24Rik      NR_015566.2      chr1       195037050     195037074
# 2    A330023F24Rik      NR_015566.2      chr1       195037091     195037113
# 3    A330023F24Rik      NR_015566.2      chr1       195037547     195037634
# 4    A330023F24Rik      NR_015566.2      chr1       195037562     195037583
# ..             ...              ...       ...             ...           ...
# 968        Zfp518a   XM_030251088.1     chr19        40894754      40894774
# 969        Zfp518a   XM_011247364.2     chr19        40894703      40894789
# 970        Zfp518a   XM_011247364.2     chr19        40894754      40894774
# 971        Zfp518a      NM_028319.1     chr19        40894754      40894774
# 972        Snora19      NR_034047.1     chr19        60774334      60774354
#
#                      miR_type               miR_Name miR_strand  \
# 0    miRNA_primary_transcript     Name=mmu-mir-29b-2          +
# 1                       miRNA  Name=mmu-miR-29b-2-5p          +
# 2                       miRNA    Name=mmu-miR-29b-3p          +
# 3    miRNA_primary_transcript       Name=mmu-mir-29c          +
# 4                       miRNA    Name=mmu-miR-29c-5p          +
# ..                        ...                    ...        ...
# 968                     miRNA      Name=mmu-miR-8092          +
# 969  miRNA_primary_transcript      Name=mmu-mir-8092          +
# 970                     miRNA      Name=mmu-miR-8092          +
# 971                     miRNA      Name=mmu-miR-8092          +
# 972                     miRNA   Name=mmu-miR-3084-3p          -
#
#                  miR_ID
# 0       Alias=MI0000712
# 1    Alias=MIMAT0017063
# 2    Alias=MIMAT0000127
# 3       Alias=MI0000577
# 4    Alias=MIMAT0004632
# ..                  ...
# 968  Alias=MIMAT0031393
# 969     Alias=MI0026019
# 970  Alias=MIMAT0031393
# 971  Alias=MIMAT0031393
# 972  Alias=MIMAT0014877
#
# [973 rows x 19 columns]

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','exon_counts','hostgene_TxStarts','hostgene_TxEnds','mature_host_mRNA_Length','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Mouse_exonic_miR_df['miRNA_type']='exonic miR'

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.loc[Mouse_exonic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_exonic_miR_df=Mouse_exonic_miR_df.drop_duplicates(subset=['miR_Name'])### get the unique list of miRNAs

# %%
Mouse_exonic_miR_df.shape
# Out:
# (170, 8)

# %%
excel_file_path=f'{current_dir}/Mouse_excel_file'

# %%
csv_file_path=f'{current_dir}/Mouse_csv_file'

# %%
Mouse_exonic_miR_df.to_csv(f'{csv_file_path}/Mouse_exonic_miR_df_unique.csv',index=False)
Mouse_exonic_miR_df.to_excel(f'{current_dir}/Mouse_excel_file/Mouse_exonic_miR_df_unique.xlsx',index=False)### save it as a exonic miRNA excel file for later use
### this step is to use for mapping intronic and intergenetic miRNAs

# %% [markdown]
# ## Mouse intronic microRNA files
# (Run this after running bedtools_mouse_intronic_miR.sh)

# %%
mRNA_miR_columns_2=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 
                  'hostgene_cdsStarts', 'hostgene_cdsEnds', 'hostgene_strand',
                 'hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 
              'miR_Name','miR_strand', 'miR_ID']

# %%
###all intronic micrornas
Mouse_intronic_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_intronic_miR_NCBI.tsv', sep='\t', header=None, names=mRNA_miR_columns_2)

# %%
Mouse_intronic_miR_df
# Out:
#       hostgene_chrom  hostgene_TxStarts  hostgene_TxEnds  hostgene_cdsStarts  \
# 0               chr1          160219173        160792925           160224215
# 1               chr1          160219173        160792925           160224215
# 2               chr1          160219173        160792972           160224215
# 3               chr1          160219173        160792972           160224215
# 4               chr1          160219173        160792987           160224215
# ...              ...                ...              ...                 ...
# 11868          chr19           52991180         53015341            52991590
# 11869          chr19           52991180         53032644            52991590
# 11870          chr19           52991180         53032644            52991590
# 11871          chr19           52991182         53038570            52991590
# 11872          chr19           52991182         53038570            52991590
#
#        hostgene_cdsEnds hostgene_strand hostgene_Name hostgene_NCBI_ID  \
# 0             160740889               -      Rabgap1l   XM_006496877.3
# 1             160740889               -      Rabgap1l   XM_006496877.3
# 2             160740889               -      Rabgap1l   XM_006496876.2
# 3             160740889               -      Rabgap1l   XM_006496876.2
# 4             160739052               -      Rabgap1l   XM_006496878.4
# ...                 ...             ...           ...              ...
# 11868          53013471               -       Xpnpep1   XM_017318075.2
# 11869          53025375               -       Xpnpep1   XM_011247159.2
# 11870          53025375               -       Xpnpep1   XM_011247159.2
# 11871          53025375               -       Xpnpep1   NM_001374834.1
# 11872          53025375               -       Xpnpep1   NM_001374834.1
#
#       miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0          chr1       160295864     160295972  miRNA_primary_transcript
# 1          chr1       160295885     160295907                     miRNA
# 2          chr1       160295864     160295972  miRNA_primary_transcript
# 3          chr1       160295885     160295907                     miRNA
# 4          chr1       160295864     160295972  miRNA_primary_transcript
# ...         ...             ...           ...                       ...
# 11868     chr19        53010679      53010701                     miRNA
# 11869     chr19        53010656      53010756  miRNA_primary_transcript
# 11870     chr19        53010679      53010701                     miRNA
# 11871     chr19        53010656      53010756  miRNA_primary_transcript
# 11872     chr19        53010679      53010701                     miRNA
#
#                 miR_Name miR_strand              miR_ID
# 0      Name=mmu-mir-1927          -     Alias=MI0009914
# 1      Name=mmu-miR-1927          -  Alias=MIMAT0009390
# 2      Name=mmu-mir-1927          -     Alias=MI0009914
# 3      Name=mmu-miR-1927          -  Alias=MIMAT0009390
# 4      Name=mmu-mir-1927          -     Alias=MI0009914
# ...                  ...        ...                 ...
# 11868  Name=mmu-miR-6407          -  Alias=MIMAT0025160
# 11869  Name=mmu-mir-6407          -     Alias=MI0021944
# 11870  Name=mmu-miR-6407          -  Alias=MIMAT0025160
# 11871  Name=mmu-mir-6407          -     Alias=MI0021944
# 11872  Name=mmu-miR-6407          -  Alias=MIMAT0025160
#
# [11873 rows x 15 columns]

# %%
Mouse_intronic_miR_df=Mouse_intronic_miR_df.drop(columns=['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds', 'hostgene_cdsStarts', 'hostgene_cdsEnds'
, 'hostgene_strand','hostgene_Name', 'hostgene_NCBI_ID'])

# %%
Mouse_intronic_miR_df['miRNA_type']='intronic miR'

# %%
Mouse_intronic_miR_df=Mouse_intronic_miR_df.loc[Mouse_intronic_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_intronic_miR_df.head()
# Out:
#   miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0      chr1       160295864     160295972  miRNA_primary_transcript
# 2      chr1       160295864     160295972  miRNA_primary_transcript
# 4      chr1       160295864     160295972  miRNA_primary_transcript
# 6      chr1       160295864     160295972  miRNA_primary_transcript
# 8      chr1       160295864     160295972  miRNA_primary_transcript
#
#             miR_Name miR_strand           miR_ID    miRNA_type
# 0  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 2  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 4  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 6  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR
# 8  Name=mmu-mir-1927          -  Alias=MI0009914  intronic miR

# %%
Mouse_intronic_miR_df.drop_duplicates(subset=['miR_Name'],inplace=True)### get the unique list of miRNAs

# %%
Mouse_intronic_miR_df.shape
# Out:
# (599, 8)

# %%
Mouse_intronic_miR_df.to_csv(f'{current_dir}/Mouse_csv_file/Mouse_intronic_miR_df_unique.csv', index=False)
Mouse_intronic_miR_df.to_excel(f'{current_dir}/Mouse_excel_file/Mouse_intronic_miR_df_unique.xlsx', index=False)

# %% [markdown]
# ### Mouse intergenetic microRNA files

# %%
columns_4=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']

# %%
###all NO host mRNA micrornas
Mouse_no_host_mRNA_miR_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mouse_miR_no_hostmRNA_NCBI.tsv', sep='\t', header=None, names=columns_4)

# %%
Mouse_no_host_mRNA_miR_df['miRNA_type']='no host mRNA miR'

# %%
Mouse_no_host_mRNA_miR_df=Mouse_no_host_mRNA_miR_df.loc[Mouse_no_host_mRNA_miR_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_no_host_mRNA_miR_df=Mouse_no_host_mRNA_miR_df.drop_duplicates(subset=['miR_Name'])### get the unique list of miRNAs

# %%
Mouse_no_host_mRNA_miR_df.shape
# Out:
# (258, 8)

# %%
Mouse_no_host_mRNA_miR_df.to_csv(f"{current_dir}/Mouse_csv_file/mouse_miR_no_hostmRNA_NCBI_unique.csv",index=False)
Mouse_no_host_mRNA_miR_df.to_excel(f"{current_dir}/Mouse_excel_file/mouse_miR_no_hostmRNA_NCBI_unique.xlsx",index=False)

# %% [markdown]
# #### Now generate a dataframe to classify all different types of miRNAs (e.g. exonic/intronic/no_host_genes).

# %% [markdown]
# ### Mouse

# %%
columns_3=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name','miR_strand', 'miR_ID']
mouse_miR_miRBase_df=pd.read_csv(f'{current_dir}/Mouse_tsv_file/mmu_finalized.tsv', sep='\t', header=None, names=columns_3)###all micrornas
mouse_miR_miRBase_df.head()
# Out:
#   miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0      chr1        12425986      12426106  miRNA_primary_transcript
# 1      chr1        12426016      12426038                     miRNA
# 2      chr1        20679010      20679082  miRNA_primary_transcript
# 3      chr1        20679017      20679039                     miRNA
# 4      chr1        20679055      20679076                     miRNA
#
#               miR_Name miR_strand              miR_ID
# 0    Name=mmu-mir-6341          +     Alias=MI0021869
# 1    Name=mmu-miR-6341          +  Alias=MIMAT0025084
# 2     Name=mmu-mir-206          +     Alias=MI0000249
# 3  Name=mmu-miR-206-5p          +  Alias=MIMAT0017004
# 4  Name=mmu-miR-206-3p          +  Alias=MIMAT0000239

# %%
Mouse_miR_type_df=pd.concat([Mouse_exonic_miR_df, Mouse_intronic_miR_df, Mouse_no_host_mRNA_miR_df], axis=0)

# %%
Mouse_miR_type_df=Mouse_miR_type_df.drop(columns=['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_ID','miR_strand'])

# %%
Mouse_miR_type_finalized_df=mouse_miR_miRBase_df.merge(Mouse_miR_type_df,on="miR_Name",how='left')

# %%
Mouse_miR_type_finalized_df=Mouse_miR_type_finalized_df.loc[Mouse_miR_type_finalized_df['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_miR_type_finalized_df.head(50)
# Out:
#     miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0        chr1        12425986      12426106  miRNA_primary_transcript
# 2        chr1        20679010      20679082  miRNA_primary_transcript
# 5        chr1        20682769      20682887  miRNA_primary_transcript
# 8        chr1        23272269      23272339  miRNA_primary_transcript
# 11       chr1        23291701      23291784  miRNA_primary_transcript
# 14       chr1        29421488      29421612  miRNA_primary_transcript
# 16       chr1        34117359      34117431  miRNA_primary_transcript
# 19       chr1        34433121      34433199  miRNA_primary_transcript
# 21       chr1        36144252      36144313  miRNA_primary_transcript
# 24       chr1        36348682      36348758  miRNA_primary_transcript
# 27       chr1        39186896      39186992  miRNA_primary_transcript
# 29       chr1        47467021      47467125  miRNA_primary_transcript
# 31       chr1        53849424      53849495  miRNA_primary_transcript
# 34       chr1        64042438      64042501  miRNA_primary_transcript
# 37       chr1        73855477      73855575  miRNA_primary_transcript
# 39       chr1        74206554      74206620  miRNA_primary_transcript
# 41       chr1        74394310      74394394  miRNA_primary_transcript
# 44       chr1        74900658      74900721  miRNA_primary_transcript
# 47       chr1        76509560      76509643  miRNA_primary_transcript
# 49       chr1        77496653      77496768  miRNA_primary_transcript
# 51       chr1        82131916      82132019  miRNA_primary_transcript
# 53       chr1        84218849      84218961  miRNA_primary_transcript
# 55       chr1        84695839      84695915  miRNA_primary_transcript
# 57       chr1        85751948      85752074  miRNA_primary_transcript
# 59       chr1        86351981      86352127  miRNA_primary_transcript
# 61       chr1        92464483      92464542  miRNA_primary_transcript
# 64       chr1        92850378      92850443  miRNA_primary_transcript
# 67       chr1        93274549      93274610  miRNA_primary_transcript
# 70       chr1        93346092      93346155  miRNA_primary_transcript
# 73       chr1        93352158      93352285  miRNA_primary_transcript
# 75       chr1       106546496     106546631  miRNA_primary_transcript
# 77       chr1       118954220     118954300  miRNA_primary_transcript
# 79       chr1       128202361     128202430  miRNA_primary_transcript
# 82       chr1       132198088     132198184  miRNA_primary_transcript
# 85       chr1       133726558     133726645  miRNA_primary_transcript
# 88       chr1       134946234     134946299  miRNA_primary_transcript
# 90       chr1       135454603     135454683  miRNA_primary_transcript
# 93       chr1       137966455     137966541  miRNA_primary_transcript
# 96       chr1       137966639     137966718  miRNA_primary_transcript
# 99       chr1       151442393     151442450  miRNA_primary_transcript
# 102      chr1       153899926     153900036  miRNA_primary_transcript
# 104      chr1       158505625     158505733  miRNA_primary_transcript
# 107      chr1       159340358     159340423  miRNA_primary_transcript
# 110      chr1       160295864     160295972  miRNA_primary_transcript
# 112      chr1       162217814     162217923  miRNA_primary_transcript
# 115      chr1       162223368     162223477  miRNA_primary_transcript
# 118      chr1       164217678     164217740  miRNA_primary_transcript
# 121      chr1       167290125     167290225  miRNA_primary_transcript
# 123      chr1       168490643     168490762  miRNA_primary_transcript
# 125      chr1       169018974     169019089  miRNA_primary_transcript
#
#                 miR_Name miR_strand           miR_ID        miRNA_type
# 0      Name=mmu-mir-6341          +  Alias=MI0021869               NaN
# 2       Name=mmu-mir-206          +  Alias=MI0000249      intronic miR
# 5      Name=mmu-mir-133b          +  Alias=MI0000821        exonic miR
# 8       Name=mmu-mir-30a          +  Alias=MI0000144  no host mRNA miR
# 11    Name=mmu-mir-30c-2          +  Alias=MI0000548  no host mRNA miR
# 14     Name=mmu-mir-6342          +  Alias=MI0021870  no host mRNA miR
# 16     Name=mmu-mir-6896          +  Alias=MI0022743      intronic miR
# 19     Name=mmu-mir-5103          -  Alias=MI0018011  no host mRNA miR
# 21     Name=mmu-mir-6897          -  Alias=MI0022744      intronic miR
# 24     Name=mmu-mir-6898          -  Alias=MI0022745      intronic miR
# 27     Name=mmu-mir-6349          -  Alias=MI0021877  no host mRNA miR
# 29     Name=mmu-mir-6350          -  Alias=MI0021878  no host mRNA miR
# 31     Name=mmu-mir-7681          +  Alias=MI0025029               NaN
# 34     Name=mmu-mir-6899          -  Alias=MI0022746      intronic miR
# 37     Name=mmu-mir-6351          -  Alias=MI0021879      intronic miR
# 39     Name=mmu-mir-1928          -  Alias=MI0009917  no host mRNA miR
# 41      Name=mmu-mir-26b          +  Alias=MI0000575      intronic miR
# 44      Name=mmu-mir-375          -  Alias=MI0000792  no host mRNA miR
# 47     Name=mmu-mir-6343          +  Alias=MI0021871  no host mRNA miR
# 49     Name=mmu-mir-6352          -  Alias=MI0021880      intronic miR
# 51     Name=mmu-mir-6344          +  Alias=MI0021872  no host mRNA miR
# 53     Name=mmu-mir-6353          -  Alias=MI0021881      intronic miR
# 55     Name=mmu-mir-5126          +  Alias=MI0018038               NaN
# 57     Name=mmu-mir-8096          +  Alias=MI0026024  no host mRNA miR
# 59     Name=mmu-mir-3535          -  Alias=MI0026036        exonic miR
# 61     Name=mmu-mir-6900          -  Alias=MI0022747      intronic miR
# 64      Name=mmu-mir-149          +  Alias=MI0000171      intronic miR
# 67     Name=mmu-mir-6901          +  Alias=MI0022748               NaN
# 70     Name=mmu-mir-6902          +  Alias=MI0022749      intronic miR
# 73     Name=mmu-mir-6345          +  Alias=MI0021873      intronic miR
# 75    Name=mmu-mir-3473f          -  Alias=MI0026016      intronic miR
# 77     Name=mmu-mir-6346          +  Alias=MI0021874               NaN
# 79    Name=mmu-mir-128-1          +  Alias=MI0000155      intronic miR
# 82     Name=mmu-mir-135b          +  Alias=MI0000646      intronic miR
# 85     Name=mmu-mir-6903          -  Alias=MI0022750               NaN
# 88    Name=mmu-mir-5104b          -  Alias=MI0040615        exonic miR
# 90     Name=mmu-mir-1231          -  Alias=MI0019183      intronic miR
# 93   Name=mmu-mir-181a-1          +  Alias=MI0000697  no host mRNA miR
# 96   Name=mmu-mir-181b-1          +  Alias=MI0000723  no host mRNA miR
# 99     Name=mmu-mir-7682          +  Alias=MI0025030      intronic miR
# 102    Name=mmu-mir-8114          +  Alias=MI0026046               NaN
# 104     Name=mmu-mir-488          +  Alias=MI0004633      intronic miR
# 107   Name=mmu-mir-1843b          +  Alias=MI0016971        exonic miR
# 110    Name=mmu-mir-1927          -  Alias=MI0009914      intronic miR
# 112  Name=mmu-mir-199a-2          +  Alias=MI0000713        exonic miR
# 115     Name=mmu-mir-214          +  Alias=MI0000698        exonic miR
# 118   Name=mmu-mir-12178          +  Alias=MI0040616        exonic miR
# 121    Name=mmu-mir-6347          +  Alias=MI0021875  no host mRNA miR
# 123    Name=mmu-mir-6348          +  Alias=MI0021876               NaN
# 125    Name=mmu-mir-6354          -  Alias=MI0021882  no host mRNA miR

# %%
Mouse_miR_type_finalized_df.shape
# Out:
# (1229, 8)

# %% [markdown]
# ## Here you will:
# ### 1) fill in the other empty cells with partially overlapped with exons
# ### 2) finalize the dataframe.

# %%
Mouse_miR_type_finalized_df['miRNA_type']=Mouse_miR_type_finalized_df['miRNA_type'].fillna("partially overlapped with exons and the opposite strands")

# %%
Mouse_miR_type_finalized_df['miR_Name']=Mouse_miR_type_finalized_df['miR_Name'].str.replace("Name=","")

# %%
Mouse_miR_type_finalized_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 2         chr1        20679010      20679082  miRNA_primary_transcript
# 5         chr1        20682769      20682887  miRNA_primary_transcript
# 8         chr1        23272269      23272339  miRNA_primary_transcript
# 11        chr1        23291701      23291784  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 3325      chrX       150547385     150547445  miRNA_primary_transcript
# 3328      chrX       151859562     151859637  miRNA_primary_transcript
# 3331      chrX       151912346     151912428  miRNA_primary_transcript
# 3334      chrX       151913214     151913321  miRNA_primary_transcript
# 3337      chrX       162874918     162874995  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID  \
# 0      mmu-mir-6341          +  Alias=MI0021869
# 2       mmu-mir-206          +  Alias=MI0000249
# 5      mmu-mir-133b          +  Alias=MI0000821
# 8       mmu-mir-30a          +  Alias=MI0000144
# 11    mmu-mir-30c-2          +  Alias=MI0000548
# ...             ...        ...              ...
# 3325   mmu-mir-3620          -  Alias=MI0025027
# 3328   mmu-mir-3113          +  Alias=MI0014111
# 3331   mmu-let-7f-2          +  Alias=MI0000563
# 3334     mmu-mir-98          +  Alias=MI0000586
# 3337  mmu-mir-3473a          -  Alias=MI0014706
#
#                                              miRNA_type
# 0     partially overlapped with exons and the opposi...
# 2                                          intronic miR
# 5                                            exonic miR
# 8                                      no host mRNA miR
# 11                                     no host mRNA miR
# ...                                                 ...
# 3325  partially overlapped with exons and the opposi...
# 3328                                         exonic miR
# 3331                                       intronic miR
# 3334                                       intronic miR
# 3337                                       intronic miR
#
# [1229 rows x 8 columns]

# %%
Mouse_miR_type_finalized_df_new=Mouse_miR_type_finalized_df.drop_duplicates(subset=['miR_Name'])

# %%
Mouse_miR_type_finalized_df.shape
# Out:
# (1229, 8)

# %%
Mouse_miR_type_finalized_df_new.shape
# Out:
# (1226, 8)

# %%
Mouse_miR_type_finalized_df_new.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_type'],
#       dtype='object')

# %% [markdown]
# ## Plotting percentages of intergenetic and intragenetic miRNAs

# %% [markdown]
# ### Mouse

# %%
Mouse_miR_type_finalized_df.columns
# Out:
# Index(['miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'miRNA_type'],
#       dtype='object')

# %%
def Hostgene_type(df, miRNAtype,hostgenetype):
    df[hostgenetype]=df[miRNAtype].apply(lambda x:"intergenic" if x=="no host mRNA miR" else "intragenic")
    return df

# %%
Hostgene_type(Mouse_miR_type_finalized_df,'miRNA_type', "main_miRNA_type")
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 2         chr1        20679010      20679082  miRNA_primary_transcript
# 5         chr1        20682769      20682887  miRNA_primary_transcript
# 8         chr1        23272269      23272339  miRNA_primary_transcript
# 11        chr1        23291701      23291784  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 3325      chrX       150547385     150547445  miRNA_primary_transcript
# 3328      chrX       151859562     151859637  miRNA_primary_transcript
# 3331      chrX       151912346     151912428  miRNA_primary_transcript
# 3334      chrX       151913214     151913321  miRNA_primary_transcript
# 3337      chrX       162874918     162874995  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID  \
# 0      mmu-mir-6341          +  Alias=MI0021869
# 2       mmu-mir-206          +  Alias=MI0000249
# 5      mmu-mir-133b          +  Alias=MI0000821
# 8       mmu-mir-30a          +  Alias=MI0000144
# 11    mmu-mir-30c-2          +  Alias=MI0000548
# ...             ...        ...              ...
# 3325   mmu-mir-3620          -  Alias=MI0025027
# 3328   mmu-mir-3113          +  Alias=MI0014111
# 3331   mmu-let-7f-2          +  Alias=MI0000563
# 3334     mmu-mir-98          +  Alias=MI0000586
# 3337  mmu-mir-3473a          -  Alias=MI0014706
#
#                                              miRNA_type main_miRNA_type
# 0     partially overlapped with exons and the opposi...      intragenic
# 2                                          intronic miR      intragenic
# 5                                            exonic miR      intragenic
# 8                                      no host mRNA miR      intergenic
# 11                                     no host mRNA miR      intergenic
# ...                                                 ...             ...
# 3325  partially overlapped with exons and the opposi...      intragenic
# 3328                                         exonic miR      intragenic
# 3331                                       intronic miR      intragenic
# 3334                                       intronic miR      intragenic
# 3337                                       intronic miR      intragenic
#
# [1229 rows x 9 columns]

# %%
mm_loci=Mouse_miR_type_finalized_df_new.groupby(Mouse_miR_type_finalized_df['main_miRNA_type']).size().reset_index(name='Count')

# %%
mm_loci
# Out:
#   main_miRNA_type  Count
# 0      intergenic    258
# 1      intragenic    968

# %%
mm_intergenic= mm_loci[mm_loci['main_miRNA_type']=='intergenic'].sum()
mm_intragenic= mm_loci[mm_loci['main_miRNA_type']=='intragenic'].sum()

# %%
#Human miR loci distribution pie Chart
labels = ['Intergenic', 'Intragenic']
sizes = [mm_intergenic['Count'],mm_intragenic['Count']]
colors = ['skyblue','lightcoral']
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of all mouse miRNome')
plt.savefig(f'{current_dir}/Mouse_eps_file/Distribution of mouse miRNome(intergenic vs intragenic).eps')
plt.show()

# %% [markdown]
# ### Intragenic Exonic sense vs antinsense

# %%
exonic_intragenic_columns=['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds', 'hostgene_cdsStart', 'hostgene_cdsEnd'
         , 'hostgene_strand','hostgene_exonCounts','hostgene_txStarts','hostgene_txEnds','mature_host_mRNA_Length',
       'hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type'
         , 'miR_Name',
       'miR_strand', 'miR_ID']

# %%
Mouse_exonicmiR_intragenic=pd.read_csv(f"{current_dir}/Mouse_tsv_file/mouse_exonic_miR_intragenic_NCBI.tsv", sep="\t",
                                      header=None,names=exonic_intragenic_columns)

# %%
Mouse_exonicmiR_antisense=pd.read_csv(f"{current_dir}/Mouse_tsv_file/mouse_exonic_miR_opposite_NCBI.tsv", sep="\t",
                                      header=None,names=exonic_intragenic_columns)

# %%
Mouse_exonicmiR_intragenic=Mouse_exonicmiR_intragenic.loc[Mouse_exonicmiR_intragenic['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_exonicmiR_intragenic=Mouse_exonicmiR_intragenic.drop_duplicates(subset=["miR_Name"])

# %%
Mouse_exonicmiR_intragenic["miR_Name"]=Mouse_exonicmiR_intragenic["miR_Name"].str.replace("Name=", "")

# %%
Mouse_exonicmiR_intragenic["host_gene_region"]="exons"

# %%
Mouse_exonicmiR_intragenic
# Out:
#      hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  \
# 0              chr1            195033822          195037908
# 3              chr1            195033822          195037908
# 6              chr1             20682712           20682958
# 9              chr1             86351980           86352127
# 11             chr1             93274604           93274718
# ...             ...                  ...                ...
# 1311          chr19              6914078            6914292
# 1317          chr19              7421913            7425908
# 1320          chr19              8888386            8888770
# 1322          chr19             40894563           40894786
# 1328          chr19             60774329           60774385
#
#       hostgene_cdsStart  hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  \
# 0             195037908        195037908               +                    8
# 3             195037908        195037908               +                    8
# 6              20682958         20682958               +                    3
# 9              86352127         86352127               -                    1
# 11             93274104         93296278               +                   31
# ...                 ...              ...             ...                  ...
# 1311            6911750          6914091               -                    6
# 1317            7417778          7423106               +                    4
# 1320            8888770          8888770               -                    1
# 1322           40911628         40916065               +                    5
# 1328           60774385         60774385               -                    1
#
#       hostgene_txStarts  hostgene_txEnds  mature_host_mRNA_Length  \
# 0             195017398        195037908                     5195
# 3             195017398        195037908                     5195
# 6              20669881         20682958                      521
# 9              86351980         86352127                      147
# 11             93235795         93301065                     9228
# ...                 ...              ...                      ...
# 1311            6910976          6921709                     1903
# 1317            7417757          7425908                     5040
# 1320            8888386          8888770                      384
# 1322           40894563         40917942                     6972
# 1328           60774329         60774385                       56
#
#       hostgene_Name hostgene_NCBI_ID miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0     A330023F24Rik      NR_015566.2      chr1       195037040     195037120
# 3     A330023F24Rik      NR_015566.2      chr1       195037547     195037634
# 6           Lincmd1      NR_131249.1      chr1        20682769      20682887
# 9           Gm24148      NR_106184.1      chr1        86351981      86352127
# 11            Sned1   XM_030252567.1      chr1        93274549      93274610
# ...             ...              ...       ...             ...           ...
# 1311          Esrra   XM_017318209.2     chr19         6914196       6914286
# 1317  2700081O15Rik   XM_011247115.3     chr19         7422573       7422642
# 1320  5730408K05Rik      NR_027866.1     chr19         8888699       8888774
# 1322        Zfp518a   XM_030251088.1     chr19        40894703      40894789
# 1328        Snora19      NR_034047.1     chr19        60774329      60774397
#
#                       miR_type        miR_Name miR_strand           miR_ID  \
# 0     miRNA_primary_transcript   mmu-mir-29b-2          +  Alias=MI0000712
# 3     miRNA_primary_transcript     mmu-mir-29c          +  Alias=MI0000577
# 6     miRNA_primary_transcript    mmu-mir-133b          +  Alias=MI0000821
# 9     miRNA_primary_transcript    mmu-mir-3535          -  Alias=MI0026036
# 11    miRNA_primary_transcript    mmu-mir-6901          +  Alias=MI0022748
# ...                        ...             ...        ...              ...
# 1311  miRNA_primary_transcript    mmu-mir-6990          -  Alias=MI0022838
# 1317  miRNA_primary_transcript    mmu-mir-6991          +  Alias=MI0022839
# 1320  miRNA_primary_transcript    mmu-mir-5136          -  Alias=MI0018048
# 1322  miRNA_primary_transcript    mmu-mir-8092          +  Alias=MI0026019
# 1328  miRNA_primary_transcript  mmu-mir-3084-2          -  Alias=MI0020958
#
#      host_gene_region
# 0               exons
# 3               exons
# 6               exons
# 9               exons
# 11              exons
# ...               ...
# 1311            exons
# 1317            exons
# 1320            exons
# 1322            exons
# 1328            exons
#
# [237 rows x 20 columns]

# %%
Mouse_exonicmiR_intragenic.shape
# Out:
# (237, 20)

# %%
Mouse_exonicmiR_antisense=Mouse_exonicmiR_antisense.loc[Mouse_exonicmiR_antisense['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_exonicmiR_antisense=Mouse_exonicmiR_antisense.drop_duplicates(subset=["miR_Name"])

# %%
Mouse_exonicmiR_antisense["miR_Name"]=Mouse_exonicmiR_antisense["miR_Name"].str.replace("Name=", "")

# %%
Mouse_exonicmiR_antisense["host_gene_region"]="exons"

# %%
Mouse_exonicmiR_antisense.shape
# Out:
# (73, 20)

# %%
Mouse_exonicmiR_antisense
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0             chr1             84695452           84696221           84370763
# 2             chr1            118952775          118961165          118961165
# 4             chr2            173701021          173702186          173695127
# 8             chr2             29845093           29845843           29871041
# 11            chr2             32045968           32051219           32083954
# ..             ...                  ...                ...                ...
# 338          chr17             25830509           25831843           25829071
# 341          chr17             26948059           26948116           26948116
# 344          chr18             11839273           11840533           11839805
# 348          chr18             70516793           70516996           70508913
# 374          chr18             34759246           34760977           34760977
#
#      hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0           84695728               -                   13           84369838
# 2          118961165               -                    2          118945048
# 4          173701119               +                    6          173659835
# 8           29881948               +                   14           29845093
# 11          32083954               -                    4           32045968
# ..               ...             ...                  ...                ...
# 338         25830590               +                    9           25829042
# 341         26948116               +                    1           26948059
# 344         11944601               +                    9           11839273
# 348         70523379               -                   10           70508679
# 374         34760977               -                    2           34758944
#
#      hostgene_txEnds  mature_host_mRNA_Length hostgene_Name hostgene_NCBI_ID  \
# 0           84696221                     3632          Dner      NM_152915.1
# 2          118961165                    15024       Gm51642   XR_003947959.1
# 4          173702186                     1840        Rab22a   XM_017316603.2
# 8           29882833                     3436        Cercam   XM_006498476.4
# 11          32083954                     7360        Fam78a   XR_003952794.1
# ..               ...                      ...           ...              ...
# 338         25831843                     2092         Jmjd8      NM_028101.5
# 341         26948116                       57       Gm51291      NR_162790.1
# 344         11945627                     3265       Cables1      NM_022021.2
# 348         70530321                     3564          Poli   NM_001289515.1
# 374         34760977                     1905        Gm3561   XR_001782441.2
#
#     miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0        chr1        84695839      84695915  miRNA_primary_transcript
# 2        chr1       118954220     118954300  miRNA_primary_transcript
# 4        chr2       173701030     173701148  miRNA_primary_transcript
# 8        chr2        29845631      29845727  miRNA_primary_transcript
# 11       chr2        32050946      32051008  miRNA_primary_transcript
# ..        ...             ...           ...                       ...
# 338     chr17        25831365      25831428  miRNA_primary_transcript
# 341     chr17        26948056      26948119  miRNA_primary_transcript
# 344     chr18        11840361      11840438  miRNA_primary_transcript
# 348     chr18        70516786      70516889  miRNA_primary_transcript
# 374     chr18        34759519      34759597  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID host_gene_region
# 0      mmu-mir-5126          +  Alias=MI0018038            exons
# 2      mmu-mir-6346          +  Alias=MI0021874            exons
# 4      mmu-mir-6340          -  Alias=MI0021868            exons
# 8    mmu-mir-219a-2          -  Alias=MI0000741            exons
# 11     mmu-mir-7674          +  Alias=MI0025015            exons
# ..              ...        ...              ...              ...
# 338    mmu-mir-3082          -  Alias=MI0014045            exons
# 341    mmu-mir-3083          -  Alias=MI0014046            exons
# 344    mmu-mir-1901          -  Alias=MI0008328            exons
# 348    mmu-mir-6357          +  Alias=MI0021885            exons
# 374   mmu-mir-12191          +  Alias=MI0040633            exons
#
# [73 rows x 20 columns]

# %%
Mouse_exonicmiR_intragenic=pd.concat([Mouse_exonicmiR_intragenic,Mouse_exonicmiR_antisense],axis=0)

# %%
Mouse_exonicmiR_intragenic.shape
# Out:
# (310, 20)

# %% [markdown]
# ### Intronic_antisense

# %%
intronic_intragenic_columns=['hostgene_chrom', 'hostgene_txStarts', 'hostgene_txEnds', 'hostgene_cdsStart', 'hostgene_cdsEnd'
         , 'hostgene_strand','hostgene_Name', 'hostgene_NCBI_ID','miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type'
         , 'miR_Name','miR_strand', 'miR_ID']

# %%
len(intronic_intragenic_columns)
# Out:
# 15

# %%
Mouse_intronicmiR_intragenic=pd.read_csv(f"{current_dir}/Mouse_tsv_file/mouse_intronic_miR_intragenic_NCBI.tsv", sep="\t",
                                      header=None,names=intronic_intragenic_columns)

# %%
Mouse_intronicmiR_antisense=pd.read_csv(f"{current_dir}/Mouse_tsv_file/mouse_intronic_opposite_miR_NCBI.tsv", sep="\t",
                                      header=None,names=intronic_intragenic_columns)

# %%
Mouse_intronicmiR_intragenic=Mouse_intronicmiR_intragenic.loc[Mouse_intronicmiR_intragenic['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_intronicmiR_intragenic=Mouse_intronicmiR_intragenic.drop_duplicates(subset=["miR_Name"])

# %%
Mouse_intronicmiR_intragenic.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_txStarts', 'hostgene_txEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_exonStarts',
#        'miR_exonEnds', 'miR_type', 'miR_Name', 'miR_strand', 'miR_ID'],
#       dtype='object')

# %%
Mouse_intronicmiR_intragenic["miR_Name"]=Mouse_intronicmiR_intragenic["miR_Name"].str.replace("Name=", "")

# %%
Mouse_intronicmiR_intragenic["host_gene_region"]= "introns"

# %%
Mouse_intronicmiR_intragenic.shape
# Out:
# (675, 16)

# %%
Mouse_intronicmiR_antisense=Mouse_intronicmiR_antisense.loc[Mouse_intronicmiR_antisense['miR_type']=="miRNA_primary_transcript"]

# %%
Mouse_intronicmiR_antisense=Mouse_intronicmiR_antisense.drop_duplicates(subset=["miR_Name"])

# %%
Mouse_intronicmiR_antisense["miR_Name"]=Mouse_intronicmiR_antisense["miR_Name"].str.replace("Name=", "")

# %%
Mouse_intronicmiR_antisense["host_gene_region"]="introns"

# %%
Mouse_intronicmiR_antisense
# Out:
#      hostgene_chrom  hostgene_txStarts  hostgene_txEnds  hostgene_cdsStart  \
# 0              chr1           53806871         53941261           53813221
# 21             chr1          158433198        158554417          158554417
# 24             chr1           12423686         12432474           12432474
# 26             chr1          168475633        168495913          168495913
# 28             chr1          185286641        185329401          185287048
# ...             ...                ...              ...                ...
# 1128          chr18           56524721         56562315           56562315
# 1140          chr19           16132683         16388520           16133325
# 1142          chr19           33137739         33392295           33392295
# 1144          chr19            6132463          6141914            6141914
# 1147          chr19           42277064         42314626           42314626
#
#       hostgene_cdsEnd hostgene_strand hostgene_Name hostgene_NCBI_ID  \
# 0            53940246               -         Hecw2   XM_017321236.2
# 21          158554417               -       Gm37679   XR_003948083.1
# 24           12432474               -       Gm39591      XR_865186.1
# 26          168495913               -       Gm39696      XR_865718.1
# 28          185329287               -         Iars2      NM_198653.3
# ...               ...             ...           ...              ...
# 1128         56562315               -       Aldh7a1      XR_385969.4
# 1140         16383394               +          Gnaq      NM_008139.6
# 1142         33392295               -          Rnls      NR_160911.1
# 1144          6141914               +  LOC115489019   XR_003952891.1
# 1147         42314626               +       Gm34347      XR_386718.4
#
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        53849424      53849495  miRNA_primary_transcript
# 21        chr1       158505625     158505733  miRNA_primary_transcript
# 24        chr1        12425986      12426106  miRNA_primary_transcript
# 26        chr1       168490643     168490762  miRNA_primary_transcript
# 28        chr1       185313319     185313385  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 1128     chr18        56538139      56538198  miRNA_primary_transcript
# 1140     chr19        16314892      16315004  miRNA_primary_transcript
# 1142     chr19        33157112      33157201  miRNA_primary_transcript
# 1144     chr19         6134801       6134863  miRNA_primary_transcript
# 1147     chr19        42280082      42280170  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID host_gene_region
# 0      mmu-mir-7681          +  Alias=MI0025029          introns
# 21      mmu-mir-488          +  Alias=MI0004633          introns
# 24     mmu-mir-6341          +  Alias=MI0021869          introns
# 26     mmu-mir-6348          +  Alias=MI0021876          introns
# 28    mmu-mir-194-1          +  Alias=MI0000236          introns
# ...             ...        ...              ...              ...
# 1128   mmu-mir-1258          +  Alias=MI0025040          introns
# 1140   mmu-mir-496b          -  Alias=MI0021942          introns
# 1142   mmu-mir-3970          +  Alias=MI0016980          introns
# 1144  mmu-mir-12193          -  Alias=MI0040636          introns
# 1147   mmu-mir-3085          -  Alias=MI0014048          introns
#
# [101 rows x 16 columns]

# %%
Mouse_intronicmiR_antisense.shape
# Out:
# (101, 16)

# %%
Mouse_intronicmiR_intragenic=pd.concat([Mouse_intronicmiR_intragenic, Mouse_intronicmiR_antisense],axis=0)

# %% [markdown]
# ### Merge exonic and intronic intragenic files and determine the transcriptional direction of miRNAs relative to the hostgenes

# %%
Mouse_exonicmiR_intragenic.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_exonCounts', 'hostgene_txStarts', 'hostgene_txEnds',
#        'mature_host_mRNA_Length', 'hostgene_Name', 'hostgene_NCBI_ID',
#        'miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name',
#        'miR_strand', 'miR_ID', 'host_gene_region'],
#       dtype='object')

# %%
Mouse_exonicmiR_intragenic=Mouse_exonicmiR_intragenic[['hostgene_NCBI_ID', 'hostgene_Name','hostgene_strand',
      'miR_type', 'miR_Name', 'miR_ID','miR_strand','host_gene_region']]

# %%
Mouse_exonicmiR_intragenic.shape
# Out:
# (310, 8)

# %%
Mouse_intronicmiR_intragenic.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_txStarts', 'hostgene_txEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_exonStarts',
#        'miR_exonEnds', 'miR_type', 'miR_Name', 'miR_strand', 'miR_ID',
#        'host_gene_region'],
#       dtype='object')

# %%
Mouse_intronicmiR_intragenic=Mouse_intronicmiR_intragenic[['hostgene_NCBI_ID', 'hostgene_Name','hostgene_strand',
      'miR_type', 'miR_Name', 'miR_ID','miR_strand','host_gene_region']]

# %%
Mouse_intronicmiR_intragenic.shape
# Out:
# (776, 8)

# %%
Mouse_intragenic_df=pd.concat([Mouse_exonicmiR_intragenic,Mouse_intronicmiR_intragenic], axis=0)

# %%
Mouse_intragenic_df.shape
# Out:
# (1086, 8)

# %%
Mouse_intronicmiR_intragenic.shape
# Out:
# (776, 8)

# %%
Mouse_exonicmiR_intragenic.shape
# Out:
# (310, 8)

# %%
Mouse_intragenic_df=Mouse_intragenic_df.drop_duplicates(subset=["miR_Name"])

# %%
Mouse_intragenic_df.shape
# Out:
# (968, 8)

# %%
def transcription_direction(df,transcription_direction,hostgene_strand,miRNA_strand):
    df[transcription_direction] = df.apply(lambda row: "sense (+)" if row[hostgene_strand] == row[miRNA_strand] else "antisense (-)", axis=1)
    return df

# %%
transcription_direction(Mouse_intragenic_df,"transcription_direction_relative_to_the_host_gene","hostgene_strand","miR_strand")
# Out:
#       hostgene_NCBI_ID  hostgene_Name hostgene_strand  \
# 0          NR_015566.2  A330023F24Rik               +
# 3          NR_015566.2  A330023F24Rik               +
# 6          NR_131249.1        Lincmd1               +
# 9          NR_106184.1        Gm24148               -
# 11      XM_030252567.1          Sned1               +
# ...                ...            ...             ...
# 12958      NM_021525.2           Rcl1               +
# 12967   XM_011247247.3         Kif20b               +
# 12987      XR_386718.4        Gm34347               +
# 12990      XR_386763.4        Gm36493               +
# 12999      NM_027559.2         Cfap43               -
#
#                        miR_type       miR_Name           miR_ID miR_strand  \
# 0      miRNA_primary_transcript  mmu-mir-29b-2  Alias=MI0000712          +
# 3      miRNA_primary_transcript    mmu-mir-29c  Alias=MI0000577          +
# 6      miRNA_primary_transcript   mmu-mir-133b  Alias=MI0000821          +
# 9      miRNA_primary_transcript   mmu-mir-3535  Alias=MI0026036          -
# 11     miRNA_primary_transcript   mmu-mir-6901  Alias=MI0022748          +
# ...                         ...            ...              ...        ...
# 12958  miRNA_primary_transcript   mmu-mir-101b  Alias=MI0000649          +
# 12967  miRNA_primary_transcript   mmu-mir-1950  Alias=MI0009941          +
# 12987  miRNA_primary_transcript   mmu-mir-3085  Alias=MI0014048          -
# 12990  miRNA_primary_transcript   mmu-mir-146b  Alias=MI0004665          +
# 12999  miRNA_primary_transcript   mmu-mir-8090  Alias=MI0026017          -
#
#       host_gene_region transcription_direction_relative_to_the_host_gene
# 0                exons                                         sense (+)
# 3                exons                                         sense (+)
# 6                exons                                         sense (+)
# 9                exons                                         sense (+)
# 11               exons                                         sense (+)
# ...                ...                                               ...
# 12958          introns                                         sense (+)
# 12967          introns                                         sense (+)
# 12987          introns                                     antisense (-)
# 12990          introns                                         sense (+)
# 12999          introns                                         sense (+)
#
# [968 rows x 9 columns]

# %%
mm_intramiR_loci=Mouse_intragenic_df.groupby(Mouse_intragenic_df["transcription_direction_relative_to_the_host_gene"]).size().reset_index(name='Count')

# %%
mm_intramiR_loci
# Out:
#   transcription_direction_relative_to_the_host_gene  Count
# 0                                     antisense (-)    146
# 1                                         sense (+)    822

# %%
mm_intramiR_sense=mm_intramiR_loci[mm_intramiR_loci["transcription_direction_relative_to_the_host_gene"]=='sense (+)'].sum()
mm_intramiR_antisense=mm_intramiR_loci[mm_intramiR_loci["transcription_direction_relative_to_the_host_gene"]=='antisense (-)'].sum()

# %%
#Human miR loci distribution pie Chart
labels = ['Sense intragenic miRNAs(+)', 'Antisense intragenic miRNAs(-)']


sizes = [mm_intramiR_sense['Count'], mm_intramiR_antisense['Count']]
colors = ['lightcoral','skyblue']
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of mouse intragenic miRNome regarding transctiption directions')
plt.savefig(f'{current_dir}/Mouse_eps_file/Distribution of mouse intragenic miRNome.eps')
plt.show()

# %% [markdown]
# ### Mouse

# %%
Mouse_miR_type_finalized_df.drop_duplicates(subset=['miR_Name'],inplace=True)####drop any duplicates to remove isoforms

# %%
Sub_mm_loci=Mouse_miR_type_finalized_df.groupby(Mouse_miR_type_finalized_df['miRNA_type']).size().reset_index(name='Count')

# %%
Sub_mm_loci
# Out:
#                                           miRNA_type  Count
# 0                                         exonic miR    170
# 1                                       intronic miR    598
# 2                                   no host mRNA miR    258
# 3  partially overlapped with exons and the opposi...    200

# %%
mm_exonic= mm_loci[Sub_mm_loci['miRNA_type']=='exonic miR'].sum()
mm_intronic= mm_loci[Sub_mm_loci['miRNA_type']=='intronic miR'].sum()
# mm_no_hostmRNA=mm_loci[Sub_mm_loci['miRNA_type']=='no host mRNA miR'].sum()
# mm_partexons=mm_loci[Sub_mm_loci['miRNA_type']=='partially overlapped with exons and the opposite strands'].sum()
# Out:
# /var/folders/hc/mc3kqq154077vn1n8slj6jsr0000gr/T/ipykernel_15312/4246006168.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mm_exonic= mm_loci[Sub_mm_loci['miRNA_type']=='exonic miR'].sum()
# /var/folders/hc/mc3kqq154077vn1n8slj6jsr0000gr/T/ipykernel_15312/4246006168.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mm_intronic= mm_loci[Sub_mm_loci['miRNA_type']=='intronic miR'].sum()

# %%
#Mouse miR loci distribution pie Chart
labels = ['Exonic miRNAs', 'Intronic miRNAs'] 
#'Intergenetic miRNAs','partially overlapped with exons and the opposite strands'are removed

sizes = [mm_exonic['Count'], mm_intronic['Count']]
#mm_no_hostmRNA['Count'],mm_partexons['Count']] are removed

colors = ['skyblue', 'lightcoral']
#'lightgreen', 'orange'are removed

plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of mouse intragenic miRNome')
plt.savefig(f'{current_dir}/Mouse_eps_file/Distribution of mouse intragenic miRNome.eps')
plt.show()

# %%
Mouse_miR_type_finalized_df
# Out:
#      miR_chrom  miR_exonStarts  miR_exonEnds                  miR_type  \
# 0         chr1        12425986      12426106  miRNA_primary_transcript
# 2         chr1        20679010      20679082  miRNA_primary_transcript
# 5         chr1        20682769      20682887  miRNA_primary_transcript
# 8         chr1        23272269      23272339  miRNA_primary_transcript
# 11        chr1        23291701      23291784  miRNA_primary_transcript
# ...        ...             ...           ...                       ...
# 3325      chrX       150547385     150547445  miRNA_primary_transcript
# 3328      chrX       151859562     151859637  miRNA_primary_transcript
# 3331      chrX       151912346     151912428  miRNA_primary_transcript
# 3334      chrX       151913214     151913321  miRNA_primary_transcript
# 3337      chrX       162874918     162874995  miRNA_primary_transcript
#
#            miR_Name miR_strand           miR_ID  \
# 0      mmu-mir-6341          +  Alias=MI0021869
# 2       mmu-mir-206          +  Alias=MI0000249
# 5      mmu-mir-133b          +  Alias=MI0000821
# 8       mmu-mir-30a          +  Alias=MI0000144
# 11    mmu-mir-30c-2          +  Alias=MI0000548
# ...             ...        ...              ...
# 3325   mmu-mir-3620          -  Alias=MI0025027
# 3328   mmu-mir-3113          +  Alias=MI0014111
# 3331   mmu-let-7f-2          +  Alias=MI0000563
# 3334     mmu-mir-98          +  Alias=MI0000586
# 3337  mmu-mir-3473a          -  Alias=MI0014706
#
#                                              miRNA_type main_miRNA_type
# 0     partially overlapped with exons and the opposi...      intragenic
# 2                                          intronic miR      intragenic
# 5                                            exonic miR      intragenic
# 8                                      no host mRNA miR      intergenic
# 11                                     no host mRNA miR      intergenic
# ...                                                 ...             ...
# 3325  partially overlapped with exons and the opposi...      intragenic
# 3328                                         exonic miR      intragenic
# 3331                                       intronic miR      intragenic
# 3334                                       intronic miR      intragenic
# 3337                                       intronic miR      intragenic
#
# [1226 rows x 9 columns]

# %%
Mouse_miR_type_finalized_df.to_csv(f'{current_dir}/Mouse_csv_file/Mouse_miR_type_finalized_df_unique.csv',index=False)
Mouse_miR_type_finalized_df.to_excel(f'{current_dir}/Mouse_excel_file/Mouse_miR_type_finalized_df_unique.xlsx',index=False)

# %% [markdown]
# ### Mouse

# %%
from EXONIC import Regions
# Out:
# importing Jupyter notebook from EXONIC.ipynb

# %%
all_exonic_mouse_exonic_miR=Regions(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR(gene_type)_NCBI.csv')

# %%
all_exonic_mouse_exonic_miR.df.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_exonCounts', 'hostgene_txStarts', 'hostgene_txEnds',
#        'mature_host_mRNA_Length', 'hostgene_Name', 'hostgene_NCBI_ID',
#        'miR_name', 'miR_chrom', 'miR_exonStarts', 'miR_exonEnds', 'miR_type',
#        'miR_strand', 'gene_type', 'pre_mRNA_length'],
#       dtype='object')

# %%
all_exonic_mouse_exonic_miR.select(['hostgene_NCBI_ID','hostgene_Name','hostgene_strand','miR_name', 
                                   'miR_strand','gene_type'])

# %%
all_exonic_mouse_exonic_miR.df.to_csv(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR_list(all_host_genes)_NCBI_no_loc.csv',index=False)
all_exonic_mouse_exonic_miR.df.to_excel(f'{current_dir}/Mouse_excel_file/mouse_exonic_miR_list(all_host_genes)_NCBI_no_loc.xlsx',index=False)
#### without the genomic coordinates

# %%
finalized_mouse_exonic_miR=Regions(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR(gene_type)_NCBI.csv')

# %%
finalized_mouse_exonic_miR.select_coding()#### select protein-coding genes

# %%
finalized_mouse_exonic_miR.add_region()
#### add a new column called region, which will contain information of location of microRNAs such as 5'UTR,3'UTR,CDS

# %%
finalized_mouse_exonic_miR.select(['hostgene_NCBI_ID','hostgene_Name','hostgene_strand','hostgene_exonCounts','miR_name', 
                                   'miR_strand','region',"pre_mRNA_length",'mature_host_mRNA_Length','gene_type'])

# %%
finalized_mouse_exonic_miR.df.head(10)
# Out:
#    hostgene_NCBI_ID hostgene_Name hostgene_strand  hostgene_exonCounts  \
# 10   XM_030248982.1         Strbp               -                   19
# 11      NM_010434.2         Hipk3               -                   16
# 12   NM_001145824.1         Hipk3               -                   16
# 13   XM_006500575.3         Lama5               -                   78
# 16   XM_011239023.3          Gad2               +                    9
# 17   XM_006498476.4        Cercam               +                   14
# 19   NM_001004174.2      AA467197               +                    5
# 21   NM_001355516.1         Rps21               +                    5
# 23   NM_001289701.1       Pde4dip               -                   47
# 24   NM_001039376.2       Pde4dip               -                   47
#
#         miR_name miR_strand region  pre_mRNA_length  mature_host_mRNA_Length  \
# 10  mmu-mir-5128          -  5'UTR         119856.0                    20102
# 11  mmu-mir-1902          -  3'UTR          68009.0                     7497
# 12  mmu-mir-1902          -  3'UTR          68009.0                     7494
# 13  mmu-mir-7005          -    CDS          49526.0                    11508
# 16  mmu-mir-3967          +  3'UTR          35260.0                     5498
# 17  mmu-mir-219b          +  5'UTR          37740.0                     3436
# 19   mmu-mir-147          +  3'UTR           3190.0                      640
# 21  mmu-mir-3091          +  5'UTR            996.0                      494
# 23  mmu-mir-7225          -  3'UTR         198880.0                     8413
# 24  mmu-mir-7225          -  3'UTR         198880.0                     8362
#
#               gene_type
# 10  protein-coding gene
# 11  protein-coding gene
# 12  protein-coding gene
# 13  protein-coding gene
# 16  protein-coding gene
# 17  protein-coding gene
# 19  protein-coding gene
# 21  protein-coding gene
# 23  protein-coding gene
# 24  protein-coding gene

# %%
finalized_mouse_exonic_miR.df.shape
# Out:
# (221, 10)

# %%
finalized_mouse_exonic_miR.df.to_csv(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR_list(protein_coding_host_genes)_NCBI.csv',index=False)
finalized_mouse_exonic_miR.df.to_excel(f'{current_dir}/Mouse_excel_file/mouse_exonic_miR_list(protein_coding_host_genes)_NCBI.xlsx',index=False)

# %%
finalized_mouse_exonic_miR_new=finalized_mouse_exonic_miR.df.drop_duplicates(subset=['miR_name'])

# %%
finalized_mouse_exonic_miR_new.to_csv(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR_list(protein_coding_host_genes)_NCBI_unique.csv',index=False)
finalized_mouse_exonic_miR_new.to_excel(f'{current_dir}/Mouse_excel_file/mouse_exonic_miR_list(protein_coding_host_genes)_NCBI_unique.xlsx',index=False)

# %% [markdown]
# ### Plot

# %% [markdown]
# ### Mouse

# %%
def move_column(df, column, new_position):
    """This function will reassign the column to a new position."""
    col = df.pop(column)
    df.insert(new_position, column, col)
    return df

# %%
move_column(mouse_exonicmiR_df,'pre_mRNA_length',9)
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0             chr1            195033822          195037908          195037908
# 1             chr1            195033822          195037908          195037908
# 2             chr1             20682712           20682958           20682958
# 3             chr1             86351980           86352127           86352127
# 4             chr1            134946233          134946299          134946299
# ..             ...                  ...                ...                ...
# 334          chr19              6829871            6830139            6829938
# 335          chr19              6914078            6914292            6911750
# 336          chr19              6914078            6914292            6911750
# 337          chr19              7421913            7425908            7417778
# 338          chr19             40894563           40894790           40911628
#
#      hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0          195037908               +                    8          195017398
# 1          195037908               +                    8          195017398
# 2           20682958               +                    3           20669881
# 3           86352127               -                    1           86351980
# 4          134946299               -                    1          134946233
# ..               ...             ...                  ...                ...
# 334          6839616               -                   17            6829871
# 335          6914091               -                    6            6910976
# 336          6914091               -                    7            6910976
# 337          7423106               +                    4            7417757
# 338         40916065               +                    4           40894563
#
#      hostgene_txEnds  pre_mRNA_length  mature_host_mRNA_Length  hostgene_Name  \
# 0          195037908          20510.0                     5195  A330023F24Rik
# 1          195037908          20510.0                     5195  A330023F24Rik
# 2           20682958          13077.0                      521        Lincmd1
# 3           86352127            147.0                      147        Gm24148
# 4          134946299             66.0                       66        Gm51265
# ..               ...              ...                      ...            ...
# 334          6842145          12274.0                     3941        Rps6ka4
# 335          6921709          10733.0                     1903          Esrra
# 336          6921814          10838.0                     2345          Esrra
# 337          7425908           8151.0                     5040  2700081O15Rik
# 338         40917942          23379.0                     6831        Zfp518a
#
#     hostgene_NCBI_ID       miR_name miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0        NR_015566.2  mmu-mir-29b-2      chr1       195037040     195037120
# 1        NR_015566.2    mmu-mir-29c      chr1       195037547     195037634
# 2        NR_131249.1   mmu-mir-133b      chr1        20682769      20682887
# 3        NR_106184.1   mmu-mir-3535      chr1        86351981      86352127
# 4        NR_162775.1  mmu-mir-5104b      chr1       134946234     134946299
# ..               ...            ...       ...             ...           ...
# 334   XM_017318261.2   mmu-mir-5046     chr19         6829886       6829944
# 335   XM_017318209.2   mmu-mir-6990     chr19         6914196       6914286
# 336   XM_030250950.1   mmu-mir-6990     chr19         6914196       6914286
# 337   XM_011247115.3   mmu-mir-6991     chr19         7422573       7422642
# 338   XM_011247364.2   mmu-mir-8092     chr19        40894703      40894789
#
#                      miR_type miR_strand            gene_type
# 0    miRNA_primary_transcript          +      non-coding gene
# 1    miRNA_primary_transcript          +      non-coding gene
# 2    miRNA_primary_transcript          +      non-coding gene
# 3    miRNA_primary_transcript          -      non-coding gene
# 4    miRNA_primary_transcript          -      non-coding gene
# ..                        ...        ...                  ...
# 334  miRNA_primary_transcript          -  protein-coding gene
# 335  miRNA_primary_transcript          -  protein-coding gene
# 336  miRNA_primary_transcript          -  protein-coding gene
# 337  miRNA_primary_transcript          +  protein-coding gene
# 338  miRNA_primary_transcript          +  protein-coding gene
#
# [339 rows x 20 columns]

# %%
### save it as a csv file for the unique list of miRNAs
mouse_exonicmiR_df_new=mouse_exonicmiR_df.drop_duplicates(subset=['miR_name'])
mouse_exonicmiR_df_new.to_csv(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR(gene_type)_NCBI_unique.csv',index=False)
mouse_exonicmiR_df_new.to_excel(f'{current_dir}/Mouse_excel_file/mouse_exonic_miR(gene_type)_NCBI_unique.xlsx',index=False)

# %%
mouse_exonicmiR_df_new
# Out:
#     hostgene_chrom  hostgene_exonStarts  hostgene_exonEnds  hostgene_cdsStart  \
# 0             chr1            195033822          195037908          195037908
# 1             chr1            195033822          195037908          195037908
# 2             chr1             20682712           20682958           20682958
# 3             chr1             86351980           86352127           86352127
# 4             chr1            134946233          134946299          134946299
# ..             ...                  ...                ...                ...
# 332          chr19              3850766            3850816            3850816
# 333          chr19              6829871            6830139            6829938
# 335          chr19              6914078            6914292            6911750
# 337          chr19              7421913            7425908            7417778
# 338          chr19             40894563           40894790           40911628
#
#      hostgene_cdsEnd hostgene_strand  hostgene_exonCounts  hostgene_txStarts  \
# 0          195037908               +                    8          195017398
# 1          195037908               +                    8          195017398
# 2           20682958               +                    3           20669881
# 3           86352127               -                    1           86351980
# 4          134946299               -                    1          134946233
# ..               ...             ...                  ...                ...
# 332          3850816               -                    1            3850766
# 333          6840547               -                   18            6829083
# 335          6914091               -                    6            6910976
# 337          7423106               +                    4            7417757
# 338         40916065               +                    4           40894563
#
#      hostgene_txEnds  pre_mRNA_length  mature_host_mRNA_Length  hostgene_Name  \
# 0          195037908          20510.0                     5195  A330023F24Rik
# 1          195037908          20510.0                     5195  A330023F24Rik
# 2           20682958          13077.0                      521        Lincmd1
# 3           86352127            147.0                      147        Gm24148
# 4          134946299             66.0                       66        Gm51265
# ..               ...              ...                      ...            ...
# 332          3850816             50.0                       50        Gm51271
# 333          6840627          11544.0                     3132        Rps6ka4
# 335          6921709          10733.0                     1903          Esrra
# 337          7425908           8151.0                     5040  2700081O15Rik
# 338         40917942          23379.0                     6831        Zfp518a
#
#     hostgene_NCBI_ID       miR_name miR_chrom  miR_exonStarts  miR_exonEnds  \
# 0        NR_015566.2  mmu-mir-29b-2      chr1       195037040     195037120
# 1        NR_015566.2    mmu-mir-29c      chr1       195037547     195037634
# 2        NR_131249.1   mmu-mir-133b      chr1        20682769      20682887
# 3        NR_106184.1   mmu-mir-3535      chr1        86351981      86352127
# 4        NR_162775.1  mmu-mir-5104b      chr1       134946234     134946299
# ..               ...            ...       ...             ...           ...
# 332      NR_162795.1  mmu-mir-12192     chr19         3850767       3850816
# 333      NM_019924.2   mmu-mir-5046     chr19         6829886       6829944
# 335   XM_017318209.2   mmu-mir-6990     chr19         6914196       6914286
# 337   XM_011247115.3   mmu-mir-6991     chr19         7422573       7422642
# 338   XM_011247364.2   mmu-mir-8092     chr19        40894703      40894789
#
#                      miR_type miR_strand            gene_type
# 0    miRNA_primary_transcript          +      non-coding gene
# 1    miRNA_primary_transcript          +      non-coding gene
# 2    miRNA_primary_transcript          +      non-coding gene
# 3    miRNA_primary_transcript          -      non-coding gene
# 4    miRNA_primary_transcript          -      non-coding gene
# ..                        ...        ...                  ...
# 332  miRNA_primary_transcript          -      non-coding gene
# 333  miRNA_primary_transcript          -  protein-coding gene
# 335  miRNA_primary_transcript          -  protein-coding gene
# 337  miRNA_primary_transcript          +  protein-coding gene
# 338  miRNA_primary_transcript          +  protein-coding gene
#
# [170 rows x 20 columns]

# %%
mouse_exonicmiR_coding_df=Regions(f'{current_dir}/Mouse_csv_file/mouse_exonic_miR_list(protein_coding_host_genes)_NCBI_unique.csv')

# %%
mouse_exonicmiR_coding_df.df.shape
# Out:
# (83, 10)

# %%
mouse_exonicmiR_coding_df.df.head()
# Out:
#   hostgene_NCBI_ID hostgene_Name hostgene_strand  hostgene_exonCounts  \
# 0   XM_030248982.1         Strbp               -                   19
# 1      NM_010434.2         Hipk3               -                   16
# 2   XM_006500575.3         Lama5               -                   78
# 3   XM_011239023.3          Gad2               +                    9
# 4   XM_006498476.4        Cercam               +                   14
#
#        miR_name miR_strand region  pre_mRNA_length  mature_host_mRNA_Length  \
# 0  mmu-mir-5128          -  5'UTR         119856.0                    20102
# 1  mmu-mir-1902          -  3'UTR          68009.0                     7497
# 2  mmu-mir-7005          -    CDS          49526.0                    11508
# 3  mmu-mir-3967          +  3'UTR          35260.0                     5498
# 4  mmu-mir-219b          +  5'UTR          37740.0                     3436
#
#              gene_type
# 0  protein-coding gene
# 1  protein-coding gene
# 2  protein-coding gene
# 3  protein-coding gene
# 4  protein-coding gene

# %%
mouse_exonic_miR_region=mouse_exonicmiR_coding_df.df.groupby(mouse_exonicmiR_coding_df.df['region']).size().reset_index(name='Mouse')

# %%
mouse_exonic_miR_region
# Out:
#                     region  Mouse
# 0                    3'UTR     32
# 1                    5'UTR     26
# 2                      CDS     21
# 3  Span from CDS and 3'UTR      3
# 4  Span from CDS and 5'UTR      1

# %%
mm_exonic_3_UTR= mouse_exonic_miR_region[mouse_exonic_miR_region['region']=='3\'UTR'].sum()
mm_exonic_5_UTR= mouse_exonic_miR_region[mouse_exonic_miR_region['region']=='5\'UTR'].sum()
mm_exonic_CDS=mouse_exonic_miR_region[mouse_exonic_miR_region['region']=='CDS'].sum()
mm_exonic_3_CDS_UTR=mouse_exonic_miR_region[mouse_exonic_miR_region['region']=='Span from CDS and 3\'UTR'].sum()
mm_exonic_5_CDS_UTR=mouse_exonic_miR_region[mouse_exonic_miR_region['region']=='Span from CDS and 5\'UTR'].sum()

# %%
labels = ['3\'UTR', '5\'UTR', 'CDS','Span from CDS and 3\'UTR','Span from CDS and 5\'UTR']
sizes = [mm_exonic_3_UTR['Mouse'], mm_exonic_5_UTR['Mouse'],mm_exonic_CDS['Mouse'],mm_exonic_3_CDS_UTR['Mouse'],mm_exonic_5_CDS_UTR['Mouse']]
colors = ['red', 'skyblue', 'green','lightgreen', 'lightcoral']
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of mouse exonic miRNA across different regions')
plt.savefig(f'{current_dir}/Mouse_eps_file/Distribution of mouse exonic miRNA across different regions of the gene.eps')
plt.show()

# %% [markdown]
# ### Coding intragenic genes(Intronic vs Exonic sense miRs)

# %% [markdown]
# ### Exonic

# %%
mouse_exonicmiR_df.shape
# Out:
# (339, 20)

# %%
mouse_exonicmiR_df_new["host_gene_region"]="exons"
# Out:
# /var/folders/hc/mc3kqq154077vn1n8slj6jsr0000gr/T/ipykernel_15312/2584326956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mouse_exonicmiR_df_new["host_gene_region"]="exons"

# %%
mouse_intramiR_exonic_gene_type=mouse_exonicmiR_df_new[[ 'hostgene_NCBI_ID', 'hostgene_Name',
       'miR_name', 'miR_type', 'miR_strand', 'gene_type','host_gene_region']]

# %% [markdown]
# ### Intronic

# %%
mouse_intronicmiR_df_gene_type=mouse_intronicmiR_df.drop_duplicates(subset=['miR_name'])

# %%
mouse_intronicmiR_df_gene_type.to_csv(f'{csv_file_path}/mouse_intronic_miR(gene_type)_NCBI_unique.csv',index=False)
mouse_intronicmiR_df_gene_type.to_excel(f'{excel_file_path}/mouse_intronic_miR(gene_type)_NCBI_unique.xlsx',index=False)

# %%
mouse_intronicmiR_df_gene_type.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_TxStarts', 'hostgene_TxEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_exonStarts',
#        'miR_exonEnds', 'miR_type', 'miR_name', 'miR_strand', 'gene_type',
#        'pre_mRNA_length'],
#       dtype='object')

# %%
mouse_intronicmiR_df_gene_type.shape
# Out:
# (599, 16)

# %%
mouse_intronicmiR_df_gene_type["host_gene_region"]="introns"
# Out:
# /var/folders/hc/mc3kqq154077vn1n8slj6jsr0000gr/T/ipykernel_15312/2816811919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mouse_intronicmiR_df_gene_type["host_gene_region"]="introns"

# %%
mouse_intronicmiR_df_gene_type.shape
# Out:
# (599, 17)

# %%
mouse_intramiR_intronic_gene_type=mouse_intronicmiR_df_gene_type[[ 'hostgene_NCBI_ID', 'hostgene_Name',
       'miR_name', 'miR_type', 'miR_strand', 'gene_type','host_gene_region']]

# %%
mouse_intramiR_intronic_gene_type.shape
# Out:
# (599, 7)

# %%
mouse_intramiR_gene_type=pd.concat([mouse_intramiR_exonic_gene_type,mouse_intramiR_intronic_gene_type],axis=0)

# %%
mouse_intramiR_gene_type
# Out:
#      hostgene_NCBI_ID  hostgene_Name        miR_name  \
# 0         NR_015566.2  A330023F24Rik   mmu-mir-29b-2
# 1         NR_015566.2  A330023F24Rik     mmu-mir-29c
# 2         NR_131249.1        Lincmd1    mmu-mir-133b
# 3         NR_106184.1        Gm24148    mmu-mir-3535
# 4         NR_162775.1        Gm51265   mmu-mir-5104b
# ...               ...            ...             ...
# 3987   XM_030250891.1          Cbwd1  mmu-mir-3084-1
# 3991      NM_021525.2           Rcl1    mmu-mir-101b
# 3994   XM_011247247.3         Kif20b    mmu-mir-1950
# 4004      XR_386763.4        Gm36493    mmu-mir-146b
# 4007      NM_027559.2         Cfap43    mmu-mir-8090
#
#                       miR_type miR_strand            gene_type  \
# 0     miRNA_primary_transcript          +      non-coding gene
# 1     miRNA_primary_transcript          +      non-coding gene
# 2     miRNA_primary_transcript          +      non-coding gene
# 3     miRNA_primary_transcript          -      non-coding gene
# 4     miRNA_primary_transcript          -      non-coding gene
# ...                        ...        ...                  ...
# 3987  miRNA_primary_transcript          -  protein-coding gene
# 3991  miRNA_primary_transcript          +  protein-coding gene
# 3994  miRNA_primary_transcript          +  protein-coding gene
# 4004  miRNA_primary_transcript          +      non-coding gene
# 4007  miRNA_primary_transcript          -  protein-coding gene
#
#      host_gene_region
# 0               exons
# 1               exons
# 2               exons
# 3               exons
# 4               exons
# ...               ...
# 3987          introns
# 3991          introns
# 3994          introns
# 4004          introns
# 4007          introns
#
# [769 rows x 7 columns]

# %%
mm_intramiR_coding=mouse_intramiR_gene_type.loc[mouse_intramiR_gene_type['gene_type']=="protein-coding gene"]

# %%
mm_intramiR_coding=mm_intramiR_coding.groupby(mm_intramiR_coding['host_gene_region']).size().reset_index(name='Count')

# %%
mm_intramiR_coding
# Out:
#   host_gene_region  Count
# 0            exons     80
# 1          introns    510

# %%
mm_exonic_intramiR_coding= mm_intramiR_coding[mm_intramiR_coding['host_gene_region']=='exons'].sum()
mm_intronic_intramiR_coding= mm_intramiR_coding[mm_intramiR_coding['host_gene_region']=='introns'].sum()

# %%
#Mouse miR loci distribution pie Chart
labels = ['Exons miRNAs', 'Intronic miRNAs']
sizes = [mm_exonic_intramiR_coding['Count'], mm_intronic_intramiR_coding['Count']]
colors = ['skyblue','lightcoral', ]
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Type of mouse intragenic coding (intronic vs exonic miRNAs) miRNome')
plt.savefig(f'{current_dir}/Mouse_eps_file/Type of mouse intragenic coding (intronic vs exonic miRNAs) miRNome.eps')
plt.show()

# %% [markdown]
# ### Noncoding

# %%
mm_intramiR_noncoding=mouse_intramiR_gene_type.loc[mouse_intramiR_gene_type['gene_type']=="non-coding gene"]

# %%
mm_intramiR_noncoding=mm_intramiR_noncoding.groupby(mm_intramiR_noncoding['host_gene_region']).size().reset_index(name='Count')

# %%
mm_intramiR_noncoding
# Out:
#   host_gene_region  Count
# 0            exons     90
# 1          introns     89

# %%
mm_exonic_intramiR_noncoding= mm_intramiR_noncoding[mm_intramiR_noncoding['host_gene_region']=='exons'].sum()
mm_intronic_intramiR_noncoding= mm_intramiR_noncoding[mm_intramiR_noncoding['host_gene_region']=='introns'].sum()

# %%
#Mouse miR loci distribution pie Chart
labels = ['Exonic miRNAs', 'Intronic miRNAs']
sizes = [mm_exonic_intramiR_noncoding['Count'], mm_intronic_intramiR_noncoding['Count']]
colors = ['skyblue','lightcoral', ]
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Type of mouse intragenic noncoding (intronic vs exonic miRNAs) miRNome')
plt.savefig(f'{current_dir}/mOuse_eps_file/Type of mouse intragenic noncoding (intronic vs exonic miRNAs) miRNome.eps')
plt.show()

# %% [markdown]
# ### Noncoding vs Coding genes(Exonic_PLOT)

# %% [markdown]
# ### Mouse

# %%
mouse_exonicmiR_df.drop_duplicates(subset=['miR_name'],inplace=True)

# %%
mouse_exonicmiR_df.shape
# Out:
# (170, 20)

# %%
mm_miR_gene_type=mouse_exonicmiR_df.groupby(mouse_exonicmiR_df['gene_type']).size().reset_index(name='Count')

# %%
mm_miR_gene_type
# Out:
#              gene_type  Count
# 0      non-coding gene     90
# 1  protein-coding gene     80

# %%
mm_exonic_proteincoding=mm_miR_gene_type[mm_miR_gene_type['gene_type']=='protein-coding gene'].sum()
mm_exonic_noncoding=mm_miR_gene_type[mm_miR_gene_type['gene_type']=='non-coding gene'].sum()

# %%
#Mouse miR loci distribution pie Chart
labels = ['protein-coding gene', 'non-coding gene']
sizes = [mm_exonic_proteincoding['Count'], mm_exonic_noncoding['Count']]
colors = ['skyblue','lightcoral', ]
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Type of mouse exonic miRNome')
plt.savefig(f'{current_dir}/Mouse_eps_file/Type of mouse exonic miRNome.eps')
plt.show()

# %% [markdown]
# ### Noncoding vs Coding genes(Intronic_PLOT)

# %% [markdown]
# ### Mouse

# %%
mouse_intronicmiR_df_gene_type=mouse_intronicmiR_df.drop_duplicates(subset=['miR_name'])

# %%
mouse_intronicmiR_df_gene_type.to_csv(f'{csv_file_path}/mouse_intronic_miR(gene_type)_NCBI_unique.csv',index=False)
mouse_intronicmiR_df_gene_type.to_excel(f'{current_dir}/Mouse_excel_file/mouse_intronic_miR(gene_type)_NCBI_unique.xlsx',index=False)

# %%
mm_miR_intronic_gene_type=mouse_intronicmiR_df.groupby(mouse_intronicmiR_df_gene_type['gene_type']).size().reset_index(name='Count')

# %%
mm_miR_intronic_gene_type
# Out:
#              gene_type  Count
# 0      non-coding gene     89
# 1  protein-coding gene    510

# %%
mm_intronic_proteincoding=mm_miR_intronic_gene_type[mm_miR_intronic_gene_type['gene_type']=='protein-coding gene'].sum()
mm_intronic_noncoding=mm_miR_intronic_gene_type[mm_miR_intronic_gene_type['gene_type']=='non-coding gene'].sum()

# %%
###Intronic
#Mouse miR loci distribution pie Chart
labels = ['protein-coding gene', 'non-coding gene']
sizes = [mm_intronic_proteincoding['Count'], mm_intronic_noncoding['Count']]
colors = ['skyblue','lightcoral', ]
plt.figure(figsize=(15, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Type of mouse intronic miRNome')
plt.savefig(f'{current_dir}/Mouse_eps_file/Type of mouse intronic miRNome.eps')
plt.show()
